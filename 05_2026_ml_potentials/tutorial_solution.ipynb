# %%
# %env CUDA_VISIBLE_DEVICES=0

import hashlib

from urllib import request
from pathlib import Path

import numpy as onp

import jax.numpy as jnp
import jax

import optax

import matplotlib.pyplot as plt

import flax

from chemtrain import quantity, trainers, ensemble
from chemtrain.data import preprocessing

from jax_md import space, partition, simulate
from jax_md_mod import custom_quantity, custom_energy
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %% [markdown]
# # Coarse-Grained Water MLPs
#
# In this tutorial, you will build two coarse-grained water machine-learning
# potentials (MLPs), implemented here with multilayer perceptrons. The first model
# is purely radial, while the second uses a learned local descriptor and Cartesian
# tensor operations to represent many-body interactions.
#
# You will then train the models in the framework **chemtrain**.
# First, you will train both models on microscopic reference data with force
# matching and compare them experimental structural measurements. Then, you will then refine the many-body model against these experimental measurements using the DiffTRe algorithm.

# %% [markdown]
# ## Data Loading
#
# The following cell loads reference mapped position and force data. For this tutorial, we express the coordinates in fractional units with respect to the simulation box.

# %%
positions_url = "https://drive.usercontent.google.com/download?id=1wVJ3cEakl5IngvuZycp0wEOsn7EQyBD8&export=download&authuser=0&confirm=t&uuid=916ca889-af2d-458f-8e97-5b1c23ea39ba&at=ALBwUgm15BEzvzbLeMs6UUzr45Lb:1777900857190"
forces_url = "https://drive.usercontent.google.com/download?id=1EgSrBa5e2-dlgG0X8fIDATbR9q3xSFwv&export=download&authuser=0&confirm=t&uuid=994f428e-a771-427f-b769-fce10ec66dd1&at=ALBwUglSh_WZNFUOOdddmeZC3JTT:1777900862535"

box = 3.12867066 # DO NOT CHANGE THIS VALUE
box = jnp.array([box, box, box])

data_dir = Path("data")
data_dir.mkdir(exist_ok=True)
positions_path = data_dir / "positions.npy"
forces_path = data_dir / "forces.npy"

if not positions_path.exists():
    request.urlretrieve(positions_url, positions_path)
if not forces_path.exists():
    request.urlretrieve(forces_url, forces_path)
 
assert hashlib.sha256(forces_path.read_bytes()).hexdigest() == 'b724eb35cc1890f5866decb0ac9b04a3f4a624bf9a323ceb89d2e99314a43687'
assert hashlib.sha256(positions_path.read_bytes()).hexdigest() == '873c7ee08bd6238531ec10dbc41e2f9651d128cdc6c61dd7dfa29f22e931bdbc'

force_dataset = preprocessing.get_dataset(forces_path, subsampling=10)
position_dataset = preprocessing.get_dataset(positions_path, subsampling=10)

position_dataset = preprocessing.scale_dataset_fractional(
    position_dataset, box
)

dataset = {
    "R": position_dataset,
    "F": force_dataset
}

print("Loaded dataset:\n\tpositions shape:", position_dataset.shape, "\n\tforces shape:", force_dataset.shape)
# Out:
# Loaded dataset:
# 	positions shape: (1000, 1000, 3)
# 	forces shape: (1000, 1000, 3)

# %% [markdown]
# ### Radial MLP
#
# We start with a simple learned **pairwise** MLP. For every neighbor pair $(i,j)$,
# the network predicts a feature, for example a pairwise energy contribution, from
# the inter-particle distance and the species of the two particles. Because the
# input depends only on the scalar distance $r_{ij}$, this architecture is
# **radial** and does not encode any angular or many-body information.
#
# For each neighbor pair we form the displacement vector $\mathbf{r}_{ij}$ and its length
# $$
# r_{ij} = \|\mathbf{r}_{ij}\|.
# $$
# We then expand the normalized distance $r_{ij}/r_\mathrm{cut}$ in a Gaussian radial basis,
# $$
# \phi_n(r_{ij}) =
# \exp\left[
# -\frac{1}{2}
# \left(
# \frac{r_{ij}/r_\mathrm{cut} - \mu_n}{\sigma_n}
# \right)^2
# \right],
# \qquad n=1,\dots,N_\mathrm{basis},
# $$
# where the centers $\mu_n$ are equally spaced in $[0,1]$.
#
# This radial basis is concatenated with learned embeddings of the sender and receiver species,
# $$
# \mathbf{x}_{ij}^{(0)}
# =
# \left[
# \mathbf{e}(Z_i),\,
# \mathbf{e}(Z_j),\,
# \phi(r_{ij})
# \right].
# $$
# The resulting edge feature is passed through a multilayer perceptron,
# $$
# \mathbf{x}_{ij}^{(\ell+1)}
# =
# \mathrm{silu}\!\left(
# W^{(\ell)} \mathbf{x}_{ij}^{(\ell)} + \mathbf{b}^{(\ell)}
# \right),
# $$
# and mapped to the final output by a linear readout,
# $$
# \mathbf{y}_{ij}
# =
# f_\mathrm{env}(r_{ij})
# \, W_\mathrm{out}\mathbf{x}_{ij}^{(L)}.
# $$
#
# The polynomial envelope
# $$
# f_\mathrm{env}(r)
# =
# 1
# -
# \frac{(p+1)(p+2)}{2}
# \left(\frac{r}{r_\mathrm{cut}}\right)^p
# +
# p(p+2)
# \left(\frac{r}{r_\mathrm{cut}}\right)^{p+1}
# -
# \frac{p(p+1)}{2}
# \left(\frac{r}{r_\mathrm{cut}}\right)^{p+2}
# $$
# ensures that the predicted interaction smoothly goes to zero at the cutoff.
#
# In the code above, the neighbor vectors `vectors`, the inter-particle distances `lengths`, the Gaussian radial basis, the species embeddings, and the envelope function are already provided. The concatenated input features `x` are therefore already constructed.
#
# What is still missing is the actual forward pass through the fully connected
# network: apply each dense layer to `x`, use the `silu` activation after every
# hidden layer, then compute the final readout `y` and multiply it by the
# envelope so that the output vanishes smoothly at the cutoff.

# %%
class GaussianRadialBasis:

    def __init__(self, num_basis: int = 8, cutoff: float = 0.5, envelope_p: int = 5):
        super().__init__()
        
        self.num_basis = num_basis
        self.cutoff = cutoff
        self.envelope_p = envelope_p


    def __call__(self, r):
        r /= self.cutoff # normalize distances to the cutoff

        # Use equally spaced Gaussians in [0, cutoff]
        centers = jnp.linspace(0, 1, self.num_basis)
        widths = jnp.full_like(centers, 0.5 * (centers[1] - centers[0]))

        # Compute Gaussian basis functions
        gaussians = jnp.exp(-0.5 * ((r[..., None] - centers) / widths) ** 2)
        # Apply envelope function to ensure smooth cutoff

        # Returns shape (num_edges, num_basis)
        return gaussians


class PolynomialEnvelope:
    
    def __init__(self, p: int = 5, cutoff: float = 0.5):
        self.p = p
        self.cutoff = cutoff

    def __call__(self, r):
        r /= self.cutoff
        return (
            1 - ((self.p + 1) * (self.p + 2) / 2) * r**self.p
            + self.p * (self.p + 2) * r**(self.p + 1)
            - (self.p * (self.p + 1) / 2) * r**(self.p + 2)
        )[..., None]


class RadialMLP(flax.linen.Module):

    num_layers: int = 2
    hidden_size: int = 64
    output_size: int = 1
    num_basis: int = 8
    num_species: int = 5
    r_cutoff: float = 0.5

    def setup(self):
        self.embedd = flax.linen.Embed(
            num_embeddings=self.num_species, features=self.hidden_size // 2)
        self.rbf = GaussianRadialBasis(
            num_basis=self.num_basis, cutoff=self.r_cutoff)
        self.envelope = PolynomialEnvelope(p=6, cutoff=self.r_cutoff)

        self.layers = [
            flax.linen.Dense(self.hidden_size) for _ in range(self.num_layers)
        ]

        self.readout = flax.linen.Dense(
            self.output_size, use_bias=False)



    def __call__(self, vectors, species, senders, receivers):
        lengths = jnp.linalg.norm(vectors, axis=-1)            
        
        x = jnp.concat([
            self.embedd(species)[senders],
            self.embedd(species)[receivers],
            self.rbf(lengths)
            ], axis=-1
        )

        #######################################################################
        # FCNN from distance and species features to radial features
        #######################################################################

        # TODO: Implement
        #
        # Inputs:
        #  - x: shape (num_edges, hidden_size) inputs to the FCNN
        # Outputs:
        #  - y: shape (num_edges, output_size) outputs of the readout layer

        for layer in self.layers:
        
            x = layer(x)
            x = jax.nn.silu(x)

        y = self.readout(x) * self.envelope(lengths)

        #######################################################################

        return y

# %% [markdown]
# ### Building the graph input
#
# Before applying the network, we must convert each configuration into a neighbor graph using a cutoff radius $r_\mathrm{cut}$. The neighbor graph defines edges
# $$
# (i,j)\in\mathcal E \quad \text{if} \quad \|\mathbf r_{ij}\| < r_\mathrm{cut},
# $$
# where $\mathbf r_{ij}$ is computed with periodic boundary conditions.
#
# The function `allocate_neighborlist(...)` estimates how many neighbors and edges are needed for the dataset and allocates a dense neighbor list of fixed size. The helper `vectors_from_nbrs(...)` then turns this neighbor list into a graph, represented by arrays:
# - `senders`: source particle indices,
# - `receivers`: neighbor indices,
# - `vectors`: displacement vectors $\mathbf r_{ij}$ for all edges.
#
# Since JAX requires static shapes under `jit`, invalid or padded neighbor entries are replaced by a fixed padding vector, and the total number of edges is truncated to at most `max_edges`. This gives a stable graph representation that can be processed efficiently by the model.
#
# Finally, `initialize_model(...)` returns two compiled functions: `init_fn` initializes the model parameters, and `apply_fn` evaluates the model on a configuration. In both cases, the neighbor list is first converted into edge features and then passed to the neural network.

# %%
r_cutoff = 0.5

def initialize_model(architecture, config, r_cutoff, displacement_fn, max_edges):
    model = architecture(**config, r_cutoff=r_cutoff)

    def vectors_from_nbrs(neighbor, position):
        num_particles, max_nbrs = neighbor.idx.shape
        senders = jnp.repeat(jnp.arange(num_particles), max_nbrs)
        receivers = neighbor.idx.flatten()

        mask = receivers < num_particles
        _, select = jax.lax.top_k(mask, k=onp.min([max_edges, mask.size]))
        receivers = jnp.take_along_axis(receivers, select, axis=0)
        senders = jnp.take_along_axis(senders, select, axis=0)

        padding = jnp.ones((3,)) * r_cutoff / jnp.sqrt(3)
        vectors = jax.vmap(displacement_fn)(position[senders], position[receivers])

        vectors = jnp.where(senders[:, None] < num_particles, vectors, padding[None, :])
        vectors = jnp.where(receivers[:, None] < num_particles, vectors, padding[None, :])

        return vectors, senders, receivers

    @jax.jit
    def init_fn(rng, position, species, neighbor):
        vectors, senders, receivers = vectors_from_nbrs(neighbor, position)

        return model.init(rng, vectors, species, senders, receivers)

    @jax.jit
    def apply_fn(params, position, species, neighbor):
        vectors, senders, receivers = vectors_from_nbrs(neighbor, position)

        return model.apply(params, vectors, species, senders, receivers)

    return init_fn, apply_fn

displacement_fn, shift_fn = space.periodic_general(box, fractional_coordinates=True)

nbrs_init, (_, max_edges, *_) = preprocessing.allocate_neighborlist(
    dataset, displacement_fn, box, r_cutoff,
    capacity_multiplier=2.5, batch_size=10,
    format=partition.Dense)

max_edges *= 2

## Actually initizalize the model

init_fn, apply_fn = initialize_model(
    RadialMLP,
    {
        "num_layers": 2,
        "hidden_size": 64,
        "num_basis": 8,
        "num_species": 1
    }, r_cutoff, displacement_fn, max_edges
)

r_init = dataset["R"][0]
nbrs_init = nbrs_init.update(r_init)
species_init = jnp.zeros(r_init.shape[0], dtype=int)

key = jax.random.PRNGKey(0)
key, split = jax.random.split(key)
init_params = init_fn(split, r_init, species_init, nbrs_init)
# Out:
# The dataset has max. 25 neighbors per particle and max. 16974 edges in total.
# Always recompute the neighbor list!

# %% [markdown]
# ### Trainable energy model
#
# To obtain a stable energy model, we combine the learned network with a simple **Lennard-Jones prior**. The total energy is
# $$
# U(\mathbf R) = U_{\mathrm{prior}}(\mathbf R) + U_{\theta}(\mathbf R).
# $$
#
# Here, `prior_energy_fn` defines a neighbor-list Lennard-Jones potential with parameters `epsilon=0.5` and `sigma=0.31`.
# The neural network then learns an additional correction on top of this prior.
#
# The function `radial_energy_fn_template(params)` returns an energy function with fixed model parameters `params`. For a given configuration, it first assigns the particle species. Since the system only contains water, all particles are mapped to the same species index. It then evaluates the prior energy and adds the sum of all learned edge contributions,
# $$
# U_{\theta}(\mathbf R) = \sum_{(i,j)\in\mathcal E} y_{ij}.
# $$
#
# In this way, the prior provides a physically reasonable baseline, while the neural network learns the remaining part of the interaction from the data.
#
# The general structure of the trainable energy model is already given. You
# still have to implement the evaluation of the prior and MLP and compute the
# total potential.

# %%
prior_energy_fn = custom_energy.customn_lennard_jones_neighbor_list(
    displacement_fn, box, epsilon=0.5, sigma=0.31,
    r_onset=0.9*r_cutoff, r_cutoff=r_cutoff,
    initialize_neighbor_list=False
)


def radial_energy_fn_template(params):

    def energy_fn(position, neighbor, **kwargs):
        # We only have water
        species = jnp.zeros((position.shape[0],), dtype=int)

        #######################################################################
        # Hybrid delta-ML potential energy function
        #######################################################################
        
        # TODO: Implement
        #
        # Inputs:
        #  - position: (n, 3) array of particle positions
        #  - species: (n,) array of particle species
        #  - neighbor: (Any) neighbor list for the current configuration
        #  - params: (Any) trained radial-network parameters from the outer scope
        #
        # Outputs:
        #  - pot: total energy of the configuration

        pot = prior_energy_fn(position, neighbor)
        pot += apply_fn(params, position, species, neighbor).sum()

        #######################################################################

        return pot

    return energy_fn

# %% [markdown]
# ### Force Matching Optimization
#
# We now train the radial energy model by **force matching**. Given an energy function
# $$
# U_\theta(\mathbf R),
# $$
# the predicted forces are obtained as
# $$
# \mathbf F_\theta(\mathbf R) = - \nabla_{\mathbf R} U_\theta(\mathbf R).
# $$
# The training objective is to minimize the discrepancy between predicted and reference forces over the dataset,
# $$
# \mathcal L_{\mathrm{FM}}(\theta)
# =
# \frac{1}{|\mathcal D|}\sum_{(\mathbf R,\mathbf F^{\mathrm{ref}})\in\mathcal D}
# \frac{1}{3N}
# \left\|
# \mathbf F_\theta(\mathbf R)-\mathbf F^{\mathrm{ref}}
# \right\|_2^2.
# $$
#
# To optimize this objective, we choose a decreasing learning-rate schedule and use Adam as the optimizer. The `ForceMatching` trainer combines the initial parameters, the optimizer, the energy model, and the preallocated neighbor list into a training loop that repeatedly evaluates the force-matching loss and updates the parameters.
#
# Finally, `set_datasets(...)` splits the data into training and validation sets. The training set is used to minimize $\mathcal L_{\mathrm{FM}}$, while the validation set provides an estimate of the same error on unseen configurations. This makes it possible to monitor both optimization progress and generalization during training.

# %%
# Define optimizer
num_iter = 100
lr_decay = optax.polynomial_schedule(init_value=1e-2, end_value=1e-3, power=2, transition_steps=num_iter)
optimizer = optax.adam(learning_rate=lr_decay)

# Initialize trainer 
radial_fm_trainer = trainers.ForceMatching(
    init_params=init_params,
    optimizer=optimizer,
    energy_fn_template=radial_energy_fn_template,
    nbrs_init=nbrs_init,
    batch_per_device=32
)

# Specify reference data
radial_fm_trainer.set_datasets(dataset, train_ratio=0.7, val_ratio=0.2)
# Out:
# /ds/project/paul/projects/reactions/external/chemtrain/chemtrain/trainers/base.py:1017: UserWarning: Batch size 32 does not divide the number of observations 700. Trainer will skip 28 samples for state training
#   warnings.warn(

# %% [markdown]
# Calling `radial_fm_trainer.train(num_iter)` starts the actual optimization and runs the force-matching training for ``num_iter`` steps. In each step, the trainer samples batches from the training set, evaluates the model forces, compares them to the reference forces, and updates the model parameters using the optimizer defined above.
#
# During training, the validation set is used to monitor performance on unseen data. This makes it possible to check whether the model is improving and whether it generalizes beyond the training configurations.

# %%
radial_fm_trainer.train(num_iter)
# Out:
# Always recompute the neighbor list!
# [Force] Found precomputed forces.
# /ds/project/paul/projects/reactions/venv/lib/python3.12/site-packages/jax/_src/numpy/reductions.py:226: UserWarning: Explicitly requested dtype float64 requested in sum is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return _reduction(a, "sum", lax.add, 0, preproc=_cast_to_numeric,
# /ds/project/paul/projects/reactions/venv/lib/python3.12/site-packages/jax/_src/numpy/reductions.py:159: UserWarning: Explicitly requested dtype float64 requested in convert_element_type is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return lax.convert_element_type(result, dtype or result_dtype)
# E0506 09:19:13.176741  971389 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.70 = f32[2,64,1]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.70_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","8"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.176798  971389 xtile_compiler.cc:401] Computation: gemm_fusion_dot.70_computation.clone {
#   parameter_0.13 = f32[64,2,543168]{0,2,1} parameter(0)
#   parameter_1.13 = f32[2,543168,1]{2,1,0} parameter(1)
#   ROOT dot = f32[2,64,1]{2,1,0} dot(parameter_0.13, parameter_1.13), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:13.361942  971381 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.71 = f32[2,64,1]{1,2,0} fusion(bitcast.2, bitcast.3), kind=kCustom, calls=gemm_fusion_dot.71_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","8"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.362141  971381 xtile_compiler.cc:401] Computation: gemm_fusion_dot.71_computation.clone {
#   parameter_1.14 = f32[2,543168,64]{2,1,0} parameter(1)
#   parameter_0.14 = f32[2,543168,1]{2,1,0} parameter(0)
#   ROOT dot = f32[2,64,1]{1,2,0} dot(parameter_1.14, parameter_0.14), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:13.389621  971400 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.44 = f32[32,72,64]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.44_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.389990  971400 xtile_compiler.cc:401] Computation: gemm_fusion_dot.44_computation.clone {
#   parameter_0.9 = f32[72,32,33948]{0,2,1} parameter(0)
#   parameter_1.9 = f32[32,33948,64]{2,1,0} parameter(1)
#   ROOT dot = f32[32,72,64]{2,1,0} dot(parameter_0.9, parameter_1.9), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:13.479258  971388 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.47 = f32[128,64,64]{2,1,0} fusion(bitcast.381, bitcast.479), kind=kCustom, calls=gemm_fusion_dot.47_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.479535  971388 xtile_compiler.cc:401] Computation: gemm_fusion_dot.47_computation.clone {
#   parameter_0.12 = f32[1086336,64]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[1086464,64]{1,0} pad(parameter_0.12, constant), padding=0_128x0_0
#   bitcast = f32[128,8488,64]{2,1,0} bitcast(pad)
#   parameter_1.12 = f32[64,1086336]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[64,1086464]{0,1} pad(parameter_1.12, constant_1), padding=0_0x0_128
#   bitcast.1 = f32[64,128,8488]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[128,64,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:13.540087  971379 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.47 = f32[64,64,64]{2,1,0} fusion(bitcast.381, bitcast.479), kind=kCustom, calls=gemm_fusion_dot.47_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.540409  971379 xtile_compiler.cc:401] Computation: gemm_fusion_dot.47_computation.clone {
#   parameter_0.12 = f32[1086336,64]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[1086464,64]{1,0} pad(parameter_0.12, constant), padding=0_128x0_0
#   bitcast = f32[64,16976,64]{2,1,0} bitcast(pad)
#   parameter_1.12 = f32[64,1086336]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[64,1086464]{0,1} pad(parameter_1.12, constant_1), padding=0_0x0_128
#   bitcast.1 = f32[64,64,16976]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[64,64,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:13.689791  971398 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.44 = f32[64,72,64]{2,1,0} fusion(bitcast.473, bitcast.390), kind=kCustom, calls=gemm_fusion_dot.44_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.690059  971398 xtile_compiler.cc:401] Computation: gemm_fusion_dot.44_computation.clone {
#   parameter_0.9 = f32[72,1086336]{0,1} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[72,1086464]{0,1} pad(parameter_0.9, constant), padding=0_0x0_128
#   bitcast = f32[72,64,16976]{0,2,1} bitcast(pad)
#   parameter_1.9 = f32[1086336,64]{1,0} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[1086464,64]{1,0} pad(parameter_1.9, constant_1), padding=0_128x0_0
#   bitcast.1 = f32[64,16976,64]{2,1,0} bitcast(pad.1)
#   ROOT dot = f32[64,72,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:13.779496  971394 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.44 = f32[32,72,64]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.44_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","128","16"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.779784  971394 xtile_compiler.cc:401] Computation: gemm_fusion_dot.44_computation.clone {
#   parameter_0.9 = f32[72,32,33948]{0,2,1} parameter(0)
#   parameter_1.9 = f32[32,33948,64]{2,1,0} parameter(1)
#   ROOT dot = f32[32,72,64]{2,1,0} dot(parameter_0.9, parameter_1.9), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:13.861598  971389 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.46 = f32[64,64,64]{2,1,0} fusion(bitcast.477, bitcast.387), kind=kCustom, calls=gemm_fusion_dot.46_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:13.862016  971389 xtile_compiler.cc:401] Computation: gemm_fusion_dot.46_computation.clone {
#   parameter_0.11 = f32[64,1086336]{0,1} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[64,1086464]{0,1} pad(parameter_0.11, constant), padding=0_0x0_128
#   bitcast = f32[64,64,16976]{0,2,1} bitcast(pad)
#   parameter_1.11 = f32[1086336,64]{1,0} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[1086464,64]{1,0} pad(parameter_1.11, constant_1), padding=0_128x0_0
#   bitcast.1 = f32[64,16976,64]{2,1,0} bitcast(pad.1)
#   ROOT dot = f32[64,64,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:14.084082  971376 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.47 = f32[2,64,64]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.47_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","8"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.084340  971376 xtile_compiler.cc:401] Computation: gemm_fusion_dot.47_computation.clone {
#   parameter_0.12 = f32[2,543168,64]{2,1,0} parameter(0)
#   parameter_1.12 = f32[64,2,543168]{0,2,1} parameter(1)
#   ROOT dot = f32[2,64,64]{2,1,0} dot(parameter_0.12, parameter_1.12), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:14.110253  971384 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.46 = f32[128,64,64]{2,1,0} fusion(bitcast.477, bitcast.387), kind=kCustom, calls=gemm_fusion_dot.46_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.110455  971384 xtile_compiler.cc:401] Computation: gemm_fusion_dot.46_computation.clone {
#   parameter_0.11 = f32[64,1086336]{0,1} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[64,1086464]{0,1} pad(parameter_0.11, constant), padding=0_0x0_128
#   bitcast = f32[64,128,8488]{0,2,1} bitcast(pad)
#   parameter_1.11 = f32[1086336,64]{1,0} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[1086464,64]{1,0} pad(parameter_1.11, constant_1), padding=0_128x0_0
#   bitcast.1 = f32[128,8488,64]{2,1,0} bitcast(pad.1)
#   ROOT dot = f32[128,64,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:14.126562  971385 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.47 = f32[128,64,64]{2,1,0} fusion(bitcast.381, bitcast.479), kind=kCustom, calls=gemm_fusion_dot.47_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.126754  971385 xtile_compiler.cc:401] Computation: gemm_fusion_dot.47_computation.clone {
#   parameter_0.12 = f32[1086336,64]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[1086464,64]{1,0} pad(parameter_0.12, constant), padding=0_128x0_0
#   bitcast = f32[128,8488,64]{2,1,0} bitcast(pad)
#   parameter_1.12 = f32[64,1086336]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[64,1086464]{0,1} pad(parameter_1.12, constant_1), padding=0_0x0_128
#   bitcast.1 = f32[64,128,8488]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[128,64,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:14.138239  971381 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.46 = f32[128,64,64]{2,1,0} fusion(bitcast.477, bitcast.387), kind=kCustom, calls=gemm_fusion_dot.46_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.138475  971381 xtile_compiler.cc:401] Computation: gemm_fusion_dot.46_computation.clone {
#   parameter_0.11 = f32[64,1086336]{0,1} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[64,1086464]{0,1} pad(parameter_0.11, constant), padding=0_0x0_128
#   bitcast = f32[64,128,8488]{0,2,1} bitcast(pad)
#   parameter_1.11 = f32[1086336,64]{1,0} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[1086464,64]{1,0} pad(parameter_1.11, constant_1), padding=0_128x0_0
#   bitcast.1 = f32[128,8488,64]{2,1,0} bitcast(pad.1)
#   ROOT dot = f32[128,64,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:14.218679  971377 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.45 = f32[32,72,64]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.45_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.219194  971377 xtile_compiler.cc:401] Computation: gemm_fusion_dot.45_computation.clone {
#   parameter_0.10 = f32[32,33948,72]{2,1,0} parameter(0)
#   parameter_1.10 = f32[64,32,33948]{0,2,1} parameter(1)
#   ROOT dot = f32[32,72,64]{2,1,0} dot(parameter_0.10, parameter_1.10), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:14.294606  971385 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.45 = f32[32,72,64]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.45_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","128","16"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.294936  971385 xtile_compiler.cc:401] Computation: gemm_fusion_dot.45_computation.clone {
#   parameter_0.10 = f32[32,33948,72]{2,1,0} parameter(0)
#   parameter_1.10 = f32[64,32,33948]{0,2,1} parameter(1)
#   ROOT dot = f32[32,72,64]{2,1,0} dot(parameter_0.10, parameter_1.10), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:14.310646  971393 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.45 = f32[64,72,64]{2,1,0} fusion(bitcast.380, bitcast.475), kind=kCustom, calls=gemm_fusion_dot.45_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.310875  971393 xtile_compiler.cc:401] Computation: gemm_fusion_dot.45_computation.clone {
#   parameter_0.10 = f32[1086336,72]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[1086464,72]{1,0} pad(parameter_0.10, constant), padding=0_128x0_0
#   bitcast = f32[64,16976,72]{2,1,0} bitcast(pad)
#   parameter_1.10 = f32[64,1086336]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[64,1086464]{0,1} pad(parameter_1.10, constant_1), padding=0_0x0_128
#   bitcast.1 = f32[64,64,16976]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[64,72,64]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["64"]}
# }
# E0506 09:19:14.376860  971396 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.46 = f32[2,64,64]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.46_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","8"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:19:14.377079  971396 xtile_compiler.cc:401] Computation: gemm_fusion_dot.46_computation.clone {
#   parameter_0.11 = f32[64,2,543168]{0,2,1} parameter(0)
#   parameter_1.11 = f32[2,543168,64]{2,1,0} parameter(1)
#   ROOT dot = f32[2,64,64]{2,1,0} dot(parameter_0.11, parameter_1.11), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0506 09:19:14.676264  971393 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0506 09:19:15.917221  971386 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0506 09:19:16.347890  971396 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Always recompute the neighbor list!
# [Force] Found precomputed forces.
# [Epoch 0]:
# 	Average train loss: 31339.50000
# 	Average val loss: 28335.96875
# 	Gradient norm: 5183215.0
# 	Elapsed time = 0.228 min (total), 0.171 min (training)
# 	Per-target losses:
# 		F | train loss: 31339.5 | val loss: 28335.96875
#
# [Epoch 1]:
# 	Average train loss: 26550.02381
# 	Average val loss: 25431.73046875
# 	Gradient norm: 25145180.0
# 	Elapsed time = 0.023 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 26550.02380952381 | val loss: 25431.73046875
#
# [Epoch 2]:
# 	Average train loss: 25314.71726
# 	Average val loss: 25241.83203125
# 	Gradient norm: 259023.78125
# 	Elapsed time = 0.020 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25314.717261904763 | val loss: 25241.83203125
#
# [Epoch 3]:
# 	Average train loss: 25215.15774
# 	Average val loss: 25214.0859375
# 	Gradient norm: 163846.5
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25215.157738095237 | val loss: 25214.0859375
#
# [Epoch 4]:
# 	Average train loss: 25184.00000
# 	Average val loss: 25211.216796875
# 	Gradient norm: 132703.03125
# 	Elapsed time = 0.020 min (total), 0.017 min (training)
# 	Per-target losses:
# 		F | train loss: 25184.0 | val loss: 25211.216796875
#
# [Epoch 5]:
# 	Average train loss: 25192.00595
# 	Average val loss: 25207.947265625
# 	Gradient norm: 146949.28125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25192.005952380954 | val loss: 25207.947265625
#
# [Epoch 6]:
# 	Average train loss: 25161.79762
# 	Average val loss: 25207.365234375
# 	Gradient norm: 7219.9326171875
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25161.79761904762 | val loss: 25207.365234375
#
# [Epoch 7]:
# 	Average train loss: 25249.10417
# 	Average val loss: 25205.869140625
# 	Gradient norm: 75966.4453125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25249.104166666668 | val loss: 25205.869140625
#
# [Epoch 8]:
# 	Average train loss: 25178.07738
# 	Average val loss: 25206.4453125
# 	Gradient norm: 11729.2041015625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25178.07738095238 | val loss: 25206.4453125
#
# [Epoch 9]:
# 	Average train loss: 25163.88988
# 	Average val loss: 25205.12890625
# 	Gradient norm: 102952.53125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25163.88988095238 | val loss: 25205.12890625
#
# [Epoch 10]:
# 	Average train loss: 25219.16369
# 	Average val loss: 25203.689453125
# 	Gradient norm: 101043.5390625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25219.16369047619 | val loss: 25203.689453125
#
# [Epoch 11]:
# 	Average train loss: 25204.07143
# 	Average val loss: 25205.28125
# 	Gradient norm: 86517.5
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25204.071428571428 | val loss: 25205.28125
#
# [Epoch 12]:
# 	Average train loss: 25174.06250
# 	Average val loss: 25202.083984375
# 	Gradient norm: 30258.25
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25174.0625 | val loss: 25202.083984375
#
# [Epoch 13]:
# 	Average train loss: 25192.39286
# 	Average val loss: 25202.853515625
# 	Gradient norm: 35591.71484375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25192.39285714286 | val loss: 25202.853515625
#
# [Epoch 14]:
# 	Average train loss: 25185.64881
# 	Average val loss: 25201.83984375
# 	Gradient norm: 123293.625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25185.64880952381 | val loss: 25201.83984375
#
# [Epoch 15]:
# 	Average train loss: 25162.26786
# 	Average val loss: 25200.63671875
# 	Gradient norm: 15108.685546875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25162.26785714286 | val loss: 25200.63671875
#
# [Epoch 16]:
# 	Average train loss: 25204.77381
# 	Average val loss: 25201.015625
# 	Gradient norm: 131572.984375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25204.77380952381 | val loss: 25201.015625
#
# [Epoch 17]:
# 	Average train loss: 25206.18155
# 	Average val loss: 25199.783203125
# 	Gradient norm: 153152.640625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25206.181547619046 | val loss: 25199.783203125
#
# [Epoch 18]:
# 	Average train loss: 25191.99405
# 	Average val loss: 25199.943359375
# 	Gradient norm: 44619.5625
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25191.994047619046 | val loss: 25199.943359375
#
# [Epoch 19]:
# 	Average train loss: 25199.83929
# 	Average val loss: 25199.55078125
# 	Gradient norm: 2597686.5
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25199.839285714286 | val loss: 25199.55078125
#
# [Epoch 20]:
# 	Average train loss: 25142.88393
# 	Average val loss: 25199.87109375
# 	Gradient norm: 121144.4375
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25142.883928571428 | val loss: 25199.87109375
#
# [Epoch 21]:
# 	Average train loss: 25191.00000
# 	Average val loss: 25198.943359375
# 	Gradient norm: 608313.3125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25191.0 | val loss: 25198.943359375
#
# [Epoch 22]:
# 	Average train loss: 25208.39583
# 	Average val loss: 25198.369140625
# 	Gradient norm: 257870.953125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25208.395833333332 | val loss: 25198.369140625
#
# [Epoch 23]:
# 	Average train loss: 25193.05655
# 	Average val loss: 25201.974609375
# 	Gradient norm: 1069873.375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25193.056547619046 | val loss: 25201.974609375
#
# [Epoch 24]:
# 	Average train loss: 25182.46429
# 	Average val loss: 25205.162109375
# 	Gradient norm: 1090544.75
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25182.464285714286 | val loss: 25205.162109375
#
# [Epoch 25]:
# 	Average train loss: 25183.15179
# 	Average val loss: 25197.931640625
# 	Gradient norm: 150506.125
# 	Elapsed time = 0.021 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25183.151785714286 | val loss: 25197.931640625
#
# [Epoch 26]:
# 	Average train loss: 25192.05357
# 	Average val loss: 25197.32421875
# 	Gradient norm: 121156.328125
# 	Elapsed time = 0.021 min (total), 0.018 min (training)
# 	Per-target losses:
# 		F | train loss: 25192.053571428572 | val loss: 25197.32421875
#
# [Epoch 27]:
# 	Average train loss: 25178.22024
# 	Average val loss: 25197.9765625
# 	Gradient norm: 65934.390625
# 	Elapsed time = 0.020 min (total), 0.017 min (training)
# 	Per-target losses:
# 		F | train loss: 25178.220238095237 | val loss: 25197.9765625
#
# [Epoch 28]:
# 	Average train loss: 25202.66667
# 	Average val loss: 25198.71875
# 	Gradient norm: 70842.4609375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25202.666666666668 | val loss: 25198.71875
#
# [Epoch 29]:
# 	Average train loss: 25178.22917
# 	Average val loss: 25197.447265625
# 	Gradient norm: 179450.171875
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25178.229166666668 | val loss: 25197.447265625
#
# [Epoch 30]:
# 	Average train loss: 25217.80060
# 	Average val loss: 25197.04296875
# 	Gradient norm: 54995.36328125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25217.800595238095 | val loss: 25197.04296875
#
# [Epoch 31]:
# 	Average train loss: 25166.48512
# 	Average val loss: 25196.248046875
# 	Gradient norm: 203399.140625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25166.48511904762 | val loss: 25196.248046875
#
# [Epoch 32]:
# 	Average train loss: 25196.67560
# 	Average val loss: 25199.73046875
# 	Gradient norm: 384090.125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25196.675595238095 | val loss: 25199.73046875
#
# [Epoch 33]:
# 	Average train loss: 25179.64583
# 	Average val loss: 25198.173828125
# 	Gradient norm: 15171.2373046875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25179.645833333332 | val loss: 25198.173828125
#
# [Epoch 34]:
# 	Average train loss: 25202.39286
# 	Average val loss: 25199.00390625
# 	Gradient norm: 822432.0625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25202.39285714286 | val loss: 25199.00390625
#
# [Epoch 35]:
# 	Average train loss: 25148.41964
# 	Average val loss: 25206.236328125
# 	Gradient norm: 5683406.5
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25148.41964285714 | val loss: 25206.236328125
#
# [Epoch 36]:
# 	Average train loss: 25182.27976
# 	Average val loss: 25195.51953125
# 	Gradient norm: 140905.375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25182.279761904763 | val loss: 25195.51953125
#
# [Epoch 37]:
# 	Average train loss: 25204.51488
# 	Average val loss: 25196.861328125
# 	Gradient norm: 525010.375
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25204.51488095238 | val loss: 25196.861328125
#
# [Epoch 38]:
# 	Average train loss: 25211.16369
# 	Average val loss: 25195.525390625
# 	Gradient norm: 361013.59375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25211.16369047619 | val loss: 25195.525390625
#
# [Epoch 39]:
# 	Average train loss: 25179.31250
# 	Average val loss: 25201.6328125
# 	Gradient norm: 1005098.6875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25179.3125 | val loss: 25201.6328125
#
# [Epoch 40]:
# 	Average train loss: 25170.24405
# 	Average val loss: 25197.763671875
# 	Gradient norm: 226600.8125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25170.244047619046 | val loss: 25197.763671875
#
# [Epoch 41]:
# 	Average train loss: 25186.32738
# 	Average val loss: 25195.1171875
# 	Gradient norm: 247304.96875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25186.32738095238 | val loss: 25195.1171875
#
# [Epoch 42]:
# 	Average train loss: 25168.00595
# 	Average val loss: 25195.533203125
# 	Gradient norm: 612103.625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25168.005952380954 | val loss: 25195.533203125
#
# [Epoch 43]:
# 	Average train loss: 25205.69048
# 	Average val loss: 25201.78515625
# 	Gradient norm: 114863.3984375
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25205.690476190477 | val loss: 25201.78515625
#
# [Epoch 44]:
# 	Average train loss: 25176.36310
# 	Average val loss: 25195.154296875
# 	Gradient norm: 92525.484375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25176.363095238095 | val loss: 25195.154296875
#
# [Epoch 45]:
# 	Average train loss: 25174.12202
# 	Average val loss: 25194.02734375
# 	Gradient norm: 102101.8828125
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25174.122023809523 | val loss: 25194.02734375
#
# [Epoch 46]:
# 	Average train loss: 25177.76190
# 	Average val loss: 25193.876953125
# 	Gradient norm: 48723.16796875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25177.761904761905 | val loss: 25193.876953125
#
# [Epoch 47]:
# 	Average train loss: 25194.88988
# 	Average val loss: 25196.4375
# 	Gradient norm: 75324.8828125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25194.88988095238 | val loss: 25196.4375
#
# [Epoch 48]:
# 	Average train loss: 25190.99107
# 	Average val loss: 25197.150390625
# 	Gradient norm: 481282.625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25190.991071428572 | val loss: 25197.150390625
#
# [Epoch 49]:
# 	Average train loss: 25172.02976
# 	Average val loss: 25202.1171875
# 	Gradient norm: 818652.25
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25172.029761904763 | val loss: 25202.1171875
#
# [Epoch 50]:
# 	Average train loss: 25190.77083
# 	Average val loss: 25195.77734375
# 	Gradient norm: 48081.04296875
# 	Elapsed time = 0.021 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25190.770833333332 | val loss: 25195.77734375
#
# [Epoch 51]:
# 	Average train loss: 25191.78274
# 	Average val loss: 25195.408203125
# 	Gradient norm: 854486.0
# 	Elapsed time = 0.021 min (total), 0.018 min (training)
# 	Per-target losses:
# 		F | train loss: 25191.782738095237 | val loss: 25195.408203125
#
# [Epoch 52]:
# 	Average train loss: 25180.20238
# 	Average val loss: 25196.224609375
# 	Gradient norm: 1453568.625
# 	Elapsed time = 0.020 min (total), 0.017 min (training)
# 	Per-target losses:
# 		F | train loss: 25180.20238095238 | val loss: 25196.224609375
#
# [Epoch 53]:
# 	Average train loss: 25151.86310
# 	Average val loss: 25193.611328125
# 	Gradient norm: 104845.6875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25151.863095238095 | val loss: 25193.611328125
#
# [Epoch 54]:
# 	Average train loss: 25235.27083
# 	Average val loss: 25194.47265625
# 	Gradient norm: 220802.96875
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25235.270833333332 | val loss: 25194.47265625
#
# [Epoch 55]:
# 	Average train loss: 25132.10417
# 	Average val loss: 25193.408203125
# 	Gradient norm: 10232.4111328125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25132.104166666668 | val loss: 25193.408203125
#
# [Epoch 56]:
# 	Average train loss: 25207.05060
# 	Average val loss: 25196.626953125
# 	Gradient norm: 1308615.75
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25207.050595238095 | val loss: 25196.626953125
#
# [Epoch 57]:
# 	Average train loss: 25188.60714
# 	Average val loss: 25193.0234375
# 	Gradient norm: 519067.84375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25188.60714285714 | val loss: 25193.0234375
#
# [Epoch 58]:
# 	Average train loss: 25190.27679
# 	Average val loss: 25200.845703125
# 	Gradient norm: 1226528.125
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25190.276785714286 | val loss: 25200.845703125
#
# [Epoch 59]:
# 	Average train loss: 25161.85417
# 	Average val loss: 25194.78125
# 	Gradient norm: 808203.375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25161.854166666668 | val loss: 25194.78125
#
# [Epoch 60]:
# 	Average train loss: 25181.28869
# 	Average val loss: 25198.080078125
# 	Gradient norm: 2261491.25
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25181.28869047619 | val loss: 25198.080078125
#
# [Epoch 61]:
# 	Average train loss: 25203.90476
# 	Average val loss: 25194.11328125
# 	Gradient norm: 775327.8125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25203.904761904763 | val loss: 25194.11328125
#
# [Epoch 62]:
# 	Average train loss: 25174.63988
# 	Average val loss: 25192.349609375
# 	Gradient norm: 915334.9375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25174.63988095238 | val loss: 25192.349609375
#
# [Epoch 63]:
# 	Average train loss: 25195.06845
# 	Average val loss: 25201.20703125
# 	Gradient norm: 869520.75
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25195.068452380954 | val loss: 25201.20703125
#
# [Epoch 64]:
# 	Average train loss: 25137.70536
# 	Average val loss: 25199.890625
# 	Gradient norm: 559316.8125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25137.70535714286 | val loss: 25199.890625
#
# [Epoch 65]:
# 	Average train loss: 25206.96726
# 	Average val loss: 25194.392578125
# 	Gradient norm: 542350.125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25206.967261904763 | val loss: 25194.392578125
#
# [Epoch 66]:
# 	Average train loss: 25218.10119
# 	Average val loss: 25194.78515625
# 	Gradient norm: 8102.29345703125
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25218.10119047619 | val loss: 25194.78515625
#
# [Epoch 67]:
# 	Average train loss: 25172.05655
# 	Average val loss: 25192.421875
# 	Gradient norm: 176202.765625
# 	Elapsed time = 0.021 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25172.056547619046 | val loss: 25192.421875
#
# [Epoch 68]:
# 	Average train loss: 25160.16964
# 	Average val loss: 25192.087890625
# 	Gradient norm: 1736150.125
# 	Elapsed time = 0.020 min (total), 0.017 min (training)
# 	Per-target losses:
# 		F | train loss: 25160.16964285714 | val loss: 25192.087890625
#
# [Epoch 69]:
# 	Average train loss: 25197.47619
# 	Average val loss: 25194.861328125
# 	Gradient norm: 192402.71875
# 	Elapsed time = 0.020 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25197.47619047619 | val loss: 25194.861328125
#
# [Epoch 70]:
# 	Average train loss: 25195.50893
# 	Average val loss: 25191.83984375
# 	Gradient norm: 207299.796875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25195.508928571428 | val loss: 25191.83984375
#
# [Epoch 71]:
# 	Average train loss: 25174.79762
# 	Average val loss: 25191.10546875
# 	Gradient norm: 109529.0234375
# 	Elapsed time = 0.019 min (total), 0.017 min (training)
# 	Per-target losses:
# 		F | train loss: 25174.79761904762 | val loss: 25191.10546875
#
# [Epoch 72]:
# 	Average train loss: 25174.67560
# 	Average val loss: 25196.208984375
# 	Gradient norm: 253625.1875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25174.675595238095 | val loss: 25196.208984375
#
# [Epoch 73]:
# 	Average train loss: 25175.32440
# 	Average val loss: 25193.853515625
# 	Gradient norm: 41973.57421875
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25175.324404761905 | val loss: 25193.853515625
#
# [Epoch 74]:
# 	Average train loss: 25187.02679
# 	Average val loss: 25191.494140625
# 	Gradient norm: 93060.875
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25187.026785714286 | val loss: 25191.494140625
#
# [Epoch 75]:
# 	Average train loss: 25178.94048
# 	Average val loss: 25191.744140625
# 	Gradient norm: 661247.1875
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25178.940476190477 | val loss: 25191.744140625
#
# [Epoch 76]:
# 	Average train loss: 25192.56250
# 	Average val loss: 25191.30859375
# 	Gradient norm: 146634.953125
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25192.5625 | val loss: 25191.30859375
#
# [Epoch 77]:
# 	Average train loss: 25179.54464
# 	Average val loss: 25190.818359375
# 	Gradient norm: 56927.99609375
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25179.54464285714 | val loss: 25190.818359375
#
# [Epoch 78]:
# 	Average train loss: 25177.17857
# 	Average val loss: 25192.0859375
# 	Gradient norm: 665809.25
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25177.178571428572 | val loss: 25192.0859375
#
# [Epoch 79]:
# 	Average train loss: 25144.37500
# 	Average val loss: 25191.46484375
# 	Gradient norm: 128963.90625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25144.375 | val loss: 25191.46484375
#
# [Epoch 80]:
# 	Average train loss: 25221.24405
# 	Average val loss: 25193.8984375
# 	Gradient norm: 107468.0625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25221.244047619046 | val loss: 25193.8984375
#
# [Epoch 81]:
# 	Average train loss: 25199.63988
# 	Average val loss: 25190.998046875
# 	Gradient norm: 83665.3359375
# 	Elapsed time = 0.019 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25199.63988095238 | val loss: 25190.998046875
#
# [Epoch 82]:
# 	Average train loss: 25153.72917
# 	Average val loss: 25192.41015625
# 	Gradient norm: 786454.375
# 	Elapsed time = 0.025 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25153.729166666668 | val loss: 25192.41015625
#
# [Epoch 83]:
# 	Average train loss: 25183.57143
# 	Average val loss: 25191.9453125
# 	Gradient norm: 73645.6015625
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25183.571428571428 | val loss: 25191.9453125
#
# [Epoch 84]:
# 	Average train loss: 25161.34524
# 	Average val loss: 25191.767578125
# 	Gradient norm: 35710.27734375
# 	Elapsed time = 0.020 min (total), 0.017 min (training)
# 	Per-target losses:
# 		F | train loss: 25161.345238095237 | val loss: 25191.767578125
#
# [Epoch 85]:
# 	Average train loss: 25227.41369
# 	Average val loss: 25191.529296875
# 	Gradient norm: 379529.5
# 	Elapsed time = 0.022 min (total), 0.019 min (training)
# 	Per-target losses:
# 		F | train loss: 25227.41369047619 | val loss: 25191.529296875
#
# [Epoch 86]:
# 	Average train loss: 25171.78274
# 	Average val loss: 25191.6328125
# 	Gradient norm: 398396.1875
# 	Elapsed time = 0.017 min (total), 0.016 min (training)
# 	Per-target losses:
# 		F | train loss: 25171.782738095237 | val loss: 25191.6328125
#
# [Epoch 87]:
# 	Average train loss: 25163.72619
# 	Average val loss: 25193.7890625
# 	Gradient norm: 821297.0
# 	Elapsed time = 0.010 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25163.72619047619 | val loss: 25193.7890625
#
# [Epoch 88]:
# 	Average train loss: 25175.96429
# 	Average val loss: 25190.353515625
# 	Gradient norm: 273004.46875
# 	Elapsed time = 0.010 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25175.964285714286 | val loss: 25190.353515625
#
# [Epoch 89]:
# 	Average train loss: 25204.50298
# 	Average val loss: 25191.544921875
# 	Gradient norm: 200525.484375
# 	Elapsed time = 0.010 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25204.502976190477 | val loss: 25191.544921875
#
# [Epoch 90]:
# 	Average train loss: 25172.15476
# 	Average val loss: 25193.587890625
# 	Gradient norm: 84674.3046875
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25172.154761904763 | val loss: 25193.587890625
#
# [Epoch 91]:
# 	Average train loss: 25184.79464
# 	Average val loss: 25191.255859375
# 	Gradient norm: 428549.46875
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25184.79464285714 | val loss: 25191.255859375
#
# [Epoch 92]:
# 	Average train loss: 25161.19048
# 	Average val loss: 25190.994140625
# 	Gradient norm: 213536.171875
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25161.190476190477 | val loss: 25190.994140625
#
# [Epoch 93]:
# 	Average train loss: 25167.04464
# 	Average val loss: 25193.6171875
# 	Gradient norm: 71010.8046875
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25167.04464285714 | val loss: 25193.6171875
#
# [Epoch 94]:
# 	Average train loss: 25219.31845
# 	Average val loss: 25190.919921875
# 	Gradient norm: 421974.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25219.318452380954 | val loss: 25190.919921875
#
# [Epoch 95]:
# 	Average train loss: 25151.84524
# 	Average val loss: 25190.44140625
# 	Gradient norm: 75109.7265625
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25151.845238095237 | val loss: 25190.44140625
#
# [Epoch 96]:
# 	Average train loss: 25193.93155
# 	Average val loss: 25189.802734375
# 	Gradient norm: 30778.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25193.931547619046 | val loss: 25189.802734375
#
# [Epoch 97]:
# 	Average train loss: 25200.79464
# 	Average val loss: 25189.974609375
# 	Gradient norm: 56489.7265625
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25200.79464285714 | val loss: 25189.974609375
#
# [Epoch 98]:
# 	Average train loss: 25157.66667
# 	Average val loss: 25192.052734375
# 	Gradient norm: 293428.9375
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25157.666666666668 | val loss: 25192.052734375
#
# [Epoch 99]:
# 	Average train loss: 25180.57143
# 	Average val loss: 25190.93359375
# 	Gradient norm: 101742.578125
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25180.571428571428 | val loss: 25190.93359375

# %% [markdown]
# The next cell visualizes the force-matching loss during training.
# Both the training and validation losses decrease, but they remain relatively
# large. This is typical in coarse-graining: the reduced model cannot reproduce
# the underlying atomistic forces exactly, and the target forces already represent
# an effective many-body projection onto the coarse-grained variables.

# %%
plt.plot(radial_fm_trainer.train_losses, label="Train Loss")
plt.plot(radial_fm_trainer.val_losses, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluating the learned pair potential
#
# This snippet probes the learned energy model on a simple two-particle system. We construct 100 configurations in which one particle is fixed at the origin and the second particle is placed at distances between `0.25` and `0.6`. The displacement is chosen along the diagonal direction, but since the radial model only depends on the distance, the exact direction is not important.
#
# A neighbor list is then initialized for this test system. The helper function `single_eval(...)` updates the neighbor list for a given configuration and evaluates the energy using the trained model parameters. Since the positions in the dataset are represented in fractional coordinates, the particle positions are divided by `box` before the energy is computed.
#
# Finally, the list comprehension evaluates the energy for all test distances
# using `radial_fm_trainer.best_params`. The resulting array `res` lets us inspect
# the effective pair interaction learned by the radial force-matching model.

# %%
r_test = jnp.ones((3,))[None, :] * jnp.linspace(0.25, 0.6, 100)[:, None] / jnp.sqrt(3)
r_test = r_test[:, None, :] * jnp.asarray([1, 0])[None, :, None]

nbrs_test = partition.neighbor_list(
    displacement_fn, box, r_cutoff=r_cutoff, format=partition.Dense
)
nbrs_test = nbrs_test.allocate(r_test[0] / box)

@jax.jit
def single_eval(params, r):
    r /= box
    nbrs = nbrs_test.update(r)
    return radial_energy_fn_template(params)(r, nbrs)

res = [single_eval(radial_fm_trainer.best_params, r) for r in r_test]

# %% [markdown]
# This plot shows the effective pair potential learned by the radial model as a
# function of the distance between two particles. The x-axis contains the
# inter-particle distance from the test configurations, and the y-axis shows the
# corresponding predicted energy.
#
# Visualizing the energy in this way makes it easy to check whether force
# matching has produced a physically plausible isotropic interaction: for example,
# a short-range repulsion, a favorable intermediate distance, and a smooth decay
# toward zero near the cutoff.

# %%
plt.plot(onp.linalg.norm(r_test[:, 0, :] - r_test[:, 1, :], axis=-1), res)
plt.xlabel("Distance")
plt.ylabel("Energy")
plt.title("Energy vs. Distance")
plt.show()

# %% [markdown]
# ### Comparing to structural reference data
#
# So far, we have trained the model to reproduce forces and inspected the resulting
# pair interaction. We now move to a structural validation and compare the model
# against reference RDF and ADF data.
#
# The radial distribution function (RDF) measures distance correlations, whereas
# the angular distribution function (ADF) probes local orientational order. These
# observables therefore test whether the learned coarse-grained interaction
# reproduces the liquid structure for the right physical reasons.
#
# We will load the reference curves, define matching observables for the
# simulation, and then compare trajectory-averaged predictions to the targets.

# %%
rdf_url = "https://raw.githubusercontent.com/tummfm/difftre/92c0790b89f0d570ed9f79663e6c06580f598345/data/experimental/O_O_RDF.csv"
adf_url = "https://raw.githubusercontent.com/tummfm/difftre/92c0790b89f0d570ed9f79663e6c06580f598345/data/experimental/O_O_O_ADF.csv"

if not (data_dir / "O_O_RDF.csv").exists():
    request.urlretrieve(rdf_url, data_dir / "O_O_RDF.csv")

if not (data_dir / "O_O_O_ADF.csv").exists():
    request.urlretrieve(adf_url, data_dir / "O_O_O_ADF.csv")

assert hashlib.sha256((data_dir / "O_O_RDF.csv").read_bytes()).hexdigest() == 'b9701ad4dd35b47985a5f4e4cd01b8351ae384a99282ad8f91dfe9e5be555192'
assert hashlib.sha256((data_dir / "O_O_O_ADF.csv").read_bytes()).hexdigest() == 'a737a25056524f04b461d899726289bfe77a4ca1308dad6151a053e0d8651613'

r_rdf, rdf = onp.loadtxt(data_dir / "O_O_RDF.csv", unpack=True)
alpha_adf, adf = onp.loadtxt(data_dir / "O_O_O_ADF.csv", unpack=True)

# %% [markdown]
# The following cell discretizes the experimental RDF and ADF and defines the
# corresponding observables for the simulation.
# A single simulated configuration gives only an instantaneous structural
# snapshot, whereas the experimental quantities are ensemble averages. For ergodic systems, we can use MD simulations to compute these averages via
# $$
# \langle a \rangle_\theta = \lim_{T\to\infty}\frac{1}{T}\int_0^T a(\mathbf{r}(t,\theta))\,dt \approx \frac{1}{S}\sum_{s=1}^S a(\mathbf{r}(t_s, \theta)),
# $$
# which we approximate practically by a finite length discretized trajectory of $S$ samples.
#
# By placing the RDF and ADF on fixed distance and angle grids, we can accumulate
# these structural correlations along the trajectory and compare the resulting
# averaged curves directly to the experimental targets.

# %%
rdf_discretization = custom_quantity.rdf_discretization(0.9, nbins=300)
adf_disc = custom_quantity.adf_discretization(nbins=150)

rdf_params = custom_quantity.RDFParams(
    jnp.interp(rdf_discretization[0], r_rdf, rdf), *rdf_discretization
)
adf_params = custom_quantity.ADFParams(
    jnp.interp(adf_disc[0], alpha_adf, adf), *adf_disc, 0.318, 0.0
)

rdf_fn = custom_quantity.init_rdf(displacement_fn, rdf_params)
adf_fn = custom_quantity.init_adf_nbrs(displacement_fn, adf_params, r_init=r_init, nbrs_init=nbrs_init)

quantities = {
    "rdf": rdf_fn,
    "adf": adf_fn
}

rdf_observable = quantity.observables.init_traj_mean_fn("rdf")
adf_observable = quantity.observables.init_traj_mean_fn("adf")
# Out:
# [ADF] Estimates 533024 max. triplets in neighbor list and 23836 max. triplets in cutoff-shell.

# %% [markdown]
# This cell sets up a simulation of the trained radial model. We define the
# Langevin parameters and sampling schedule, assign a mass to each coarse-grained
# water particle, and choose a random configuration from the dataset as the
# initial structure.
#
# Using this configuration, we update the neighbor list, initialize the
# simulator, and construct the corresponding `reference_state` with the best
# radial force-matching parameters. This state serves as the starting point for
# the trajectory generation in the next step.

# %%
dt = 0.01
gamma = 100.
kT = quantity.kb * 300.0

timings = ensemble.sampling.process_printouts(
    time_step=dt, total_time=60.0, print_every=0.1,
    t_equilib=10.0
)

masses = jnp.ones((position_dataset.shape[1],)) * 18.02

key, split = jax.random.split(key)
selection = jax.random.choice(
    split, jnp.arange(position_dataset.shape[0]), shape=(1,), replace=False)
r_init = position_dataset[selection, ...].squeeze(0)
nbrs_init = nbrs_init.update(r_init)

init_ref_state, sim_template = ensemble.sampling.initialize_simulator_template(
    simulate.nvt_langevin, shift_fn=shift_fn, nbrs=nbrs_init,
    init_with_PRNGKey=True, extra_simulator_kwargs={"kT": kT, "gamma": gamma, "dt": dt}
)

key, split = jax.random.split(key)
reference_state = init_ref_state(
    split, r_init,
    energy_or_force_fn=radial_energy_fn_template(radial_fm_trainer.best_params),
    init_sim_kwargs={"mass": masses, "neighbor": nbrs_init}
)
# Out:
# Always recompute the neighbor list!
# Always recompute the neighbor list!

# %% [markdown]
# We now combine the simulator, learned energy model, sampling protocol, and
# structural observables into a trajectory generator. This lets us simulate from
# the previously initialized reference state with the current model parameters and
# record the quantities of interest along the trajectory.

# %%
trajectory_generator = ensemble.sampling.trajectory_generator_init(
    sim_template, radial_energy_fn_template, timings, quantities)

trajectory = trajectory_generator(radial_fm_trainer.params, reference_state, box=box)

print(f"Average kT: {trajectory.aux['kT'].mean()}")
# Out:
# Always recompute the neighbor list!
# Always recompute the neighbor list!
# Average kT: 2.45186185836792

# %% [markdown]
# The figure compares the trajectory-averaged structural observables of the
# radial model to the corresponding experimental reference curves: the left panel
# shows the RDF, and the right panel shows the ADF.
#
# The RDF is reproduced only qualitatively, with visible deviations in peak
# heights and positions. This means that the effective pair structure is captured
# only approximately.
#
# The discrepancy is substantially larger for the ADF, which probes three-body
# angular correlations and local orientational order. This is the key limitation
# of a purely radial coarse-grained model: isotropic pair interactions can recover
# part of the distance-dependent structure, but they do not explicitly represent
# the directional many-body correlations that organize liquid water.

# %%
plt.figure(figsize=(12, 5), layout="constrained")
plt.subplot(1, 2, 1)
plt.plot(rdf_params.rdf_bin_centers, rdf_params.reference, label="Experimental RDF")
plt.plot(rdf_params.rdf_bin_centers, rdf_observable(trajectory.aux), label="Simulated RDF")
plt.xlabel("Distance")
plt.ylabel("RDF")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(adf_params.adf_bin_centers, adf_params.reference, label="Experimental ADF")
plt.plot(adf_params.adf_bin_centers, adf_observable(trajectory.aux), label="Simulated ADF")
plt.legend()
plt.xlabel("Angle")
plt.ylabel("ADF")
# Out:
# Text(0, 0.5, 'ADF')

# %% [markdown]
# ### Local many-body MLP
#
# We now move from a radial pair model to a local many-body MLP. Instead of assigning features only to edges, we first build a fixed-size descriptor for each central particle from its local environment
# $$
# \chi_i = \{(r_{ij}, Z_j) \mid j \in \mathcal N(i)\},
# $$
# and then map this descriptor to a particle-wise output.
#
# As before, the radial network processes each neighbor pair and returns learned edge features. These are split into scalar and directional channels,
# $$
# (s_{ij}, v_{ij}) = \mathrm{RadialMLP}(\mathbf r_{ij}, Z_i, Z_j).
# $$
# The scalar channels are summed over the neighborhood,
# $$
# S_i = \sum_{j\in\mathcal N(i)} s_{ij},
# $$
# while the directional channels are multiplied by the unit vectors
# $$
# \hat{\mathbf r}_{ij} = \frac{\mathbf r_{ij}}{\|\mathbf r_{ij}\|},
# $$
# and pooled as
# $$
# \mathbf V_i = \sum_{j\in\mathcal N(i)} v_{ij}\hat{\mathbf r}_{ij}.
# $$
#
# The quantity $\|\mathbf V_i\|^2$ is rotationally invariant, but still depends on relative neighbor directions. After expansion, it contains scalar products of the form
# $$
# \hat{\mathbf r}_{ij}\cdot\hat{\mathbf r}_{ik} = \cos \angle(jik),
# $$
# so it carries angular information.
#
# Finally, we combine scalar and directional information into the local descriptor
# $$
# \mathbf G_i = [S_i, \|\mathbf V_i\|^2],
# $$
# and pass it through a second MLP and a linear readout. In this way, the model
# remains local and permutation-invariant while going beyond purely radial
# interactions.
#
# In the next cell, the radial edge model `self.radial`, the hidden layers, and
# the readout are already provided. What remains is the forward construction of
# the local many-body descriptor: compute edge features with the radial model,
# split them into scalar and directional channels, convert the directional part
# into vectors using the normalized displacement directions, pool both
# contributions over neighbors with `segment_sum`, and build the invariant node
# features by concatenating the summed scalar channels with the squared norm of
# the pooled vector features. These node features are then passed through the
# final MLP and readout.

# %%
class LocalManybodyMLP(flax.linen.Module):

    num_layers: int = 2
    hidden_size: int = 64
    num_species: int = 5
    r_cutoff: float = 0.5
    num_basis: int = 8
    readout_size: int = 1

    def setup(self):
        self.radial = RadialMLP(
            num_layers=self.num_layers,
            hidden_size=self.hidden_size,
            num_basis=self.num_basis,
            r_cutoff=self.r_cutoff,
            output_size=self.hidden_size
        )
        self.layers = [
            flax.linen.Dense(self.hidden_size) for _ in range(self.num_layers)
        ]
        self.readout = flax.linen.Dense(self.readout_size, use_bias=False)

    def __call__(self, vectors, species, senders, receivers):
        # Pool over all neighbors
        s, v = jnp.split(self.radial(vectors, species, senders, receivers), 2, axis=-1)

        #######################################################################
        # Neighbor pooling and per-particle feature construction
        #######################################################################

        # TODO: Implement
        #
        # Inputs:
        #  - s: shape (num_edges, hidden_size // 2) scalar features
        #  - v: shape (num_edges, hidden_size // 2) vector features
        # Outputs:
        #  - node_feats: shape (num_particles, hidden_size) per-particle features

        d = vectors / jnp.linalg.norm(vectors, axis=-1, keepdims=True)
        v = v[..., None] * d[..., None, :]

        scalar_node_feats = jax.ops.segment_sum(s, senders, num_segments=species.shape[0])
        vector_node_feats = jax.ops.segment_sum(v, senders, num_segments=species.shape[0])

        node_feats = jnp.concatenate([
            scalar_node_feats,
            jnp.sum(vector_node_feats ** 2, axis=-1)
            ], axis=-1
        )

        #######################################################################

        for layer in self.layers:
            node_feats = layer(node_feats)
            node_feats = jax.nn.silu(node_feats)

        return self.readout(node_feats)

# %%
architecture = LocalManybodyMLP
config = {
    "num_layers": 2,
    "hidden_size": 32,
    "num_basis": 8,
    "num_species": 1
}

###############################################################################
# Initializes the model with the same utilities as before
###############################################################################

# TODO: Implement
#
# Inputs:
# - architecture: the model architecture class (e.g. LocalManybodyMLP)
# - config: a dictionary of configuration parameters for the model architecture
# - r_cutoff, displacement_fn, max_edges: same as before
# - displacement_fn: the displacement function for computing neighbor vectors
#
# Outputs:
# - init_fn: a function that initializes the model parameters given a PRNGKey and input
# - apply_fn: a function that applies the model given parameters and input


init_fn, apply_fn = initialize_model(
    architecture, config, r_cutoff, displacement_fn, max_edges)

###############################################################################

key = jax.random.PRNGKey(0)
key, split = jax.random.split(key)
init_params = init_fn(split, r_init, species_init, nbrs_init)

print("Model initialized with parameters:")
print(jax.tree.map(lambda x: x.shape, init_params))
# Out:
# Model initialized with parameters:
# {'params': {'layers_0': {'bias': (32,), 'kernel': (32, 32)}, 'layers_1': {'bias': (32,), 'kernel': (32, 32)}, 'radial': {'embedd': {'embedding': (5, 16)}, 'layers_0': {'bias': (32,), 'kernel': (40, 32)}, 'layers_1': {'bias': (32,), 'kernel': (32, 32)}, 'readout': {'kernel': (32, 32)}}, 'readout': {'kernel': (32, 1)}}}

# %% [markdown]
# The next cell turns the local many-body network into a trainable energy model.
# As in the radial case, we add a simple prior interaction so that the learned
# model does not have to represent the entire short-range physics from scratch.
# The neural network then learns a flexible correction on top of this baseline.

# %%
prior_energy_fn = custom_energy.customn_lennard_jones_neighbor_list(
    displacement_fn, box, epsilon=0.5, sigma=0.31,
    r_onset=0.9*r_cutoff, r_cutoff=r_cutoff,
    initialize_neighbor_list=False
)


def manybody_energy_fn_template(params):

    def energy_fn(position, neighbor, **kwargs):

        # We only have CG water
        species = jnp.zeros((position.shape[0],), dtype=int)
        #######################################################################
        # Hybrid delta-ML potential energy function
        #######################################################################
        
        # TODO: Implement
        #
        # Inputs:
        #  - position: (n, 3) array of particle positions
        #  - species: (n,) array of particle species
        #  - neighbor: (Any) neighbor list for the current configuration
        #  - params: (Any) trained radial-network parameters from the outer scope
        #
        # Outputs:
        #  - pot: total energy of the configuration

        pot = prior_energy_fn(position, neighbor)
        pot += apply_fn(params, position, species, neighbor).sum()

        #######################################################################

        return pot

    return energy_fn

# %% [markdown]
# We first train the many-body model with force matching, exactly as before.
# The main difference is representational power: because the descriptor
# $\mathbf G_i$ contains angular information from the local environment, the
# network can fit effective coarse-grained forces that a purely radial model
# cannot express.

# %%
# Define optimizer
num_iter = 100
lr_decay = optax.polynomial_schedule(init_value=1e-2, end_value=1e-3, power=2, transition_steps=num_iter)
optimizer = optax.adam(learning_rate=lr_decay)

# Initialize trainer 
manybody_fm_trainer = trainers.ForceMatching(
    init_params=init_params,
    optimizer=optimizer,
    energy_fn_template=manybody_energy_fn_template,
    nbrs_init=nbrs_init,
    batch_per_device=32
)

# Specify reference data
manybody_fm_trainer.set_datasets(dataset, train_ratio=0.7, val_ratio=0.2)

# Train the model
manybody_fm_trainer.train(num_iter)
# Out:
# Always recompute the neighbor list!
# [Force] Found precomputed forces.
# E0506 09:23:24.663121  971388 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.78 = f32[2,40,32]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.78_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","8"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:23:24.663423  971388 xtile_compiler.cc:401] Computation: gemm_fusion_dot.78_computation.clone {
#   parameter_0.25 = f32[2,543168,40]{2,1,0} parameter(0)
#   parameter_1.25 = f32[32,2,543168]{0,2,1} parameter(1)
#   ROOT dot = f32[2,40,32]{2,1,0} dot(parameter_0.25, parameter_1.25), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:23:24.714775  971375 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.78 = f32[128,40,32]{2,1,0} fusion(bitcast.550, bitcast.696), kind=kCustom, calls=gemm_fusion_dot.78_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:23:24.715284  971375 xtile_compiler.cc:401] Computation: gemm_fusion_dot.78_computation.clone {
#   parameter_0.25 = f32[1086336,40]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[1086464,40]{1,0} pad(parameter_0.25, constant), padding=0_128x0_0
#   bitcast = f32[128,8488,40]{2,1,0} bitcast(pad)
#   parameter_1.25 = f32[32,1086336]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[32,1086464]{0,1} pad(parameter_1.25, constant_1), padding=0_0x0_128
#   bitcast.1 = f32[32,128,8488]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[128,40,32]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:23:24.794916  971382 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.78 = f32[128,40,32]{2,1,0} fusion(bitcast.550, bitcast.696), kind=kCustom, calls=gemm_fusion_dot.78_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:23:24.795597  971382 xtile_compiler.cc:401] Computation: gemm_fusion_dot.78_computation.clone {
#   parameter_0.25 = f32[1086336,40]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[1086464,40]{1,0} pad(parameter_0.25, constant), padding=0_128x0_0
#   bitcast = f32[128,8488,40]{2,1,0} bitcast(pad)
#   parameter_1.25 = f32[32,1086336]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[32,1086464]{0,1} pad(parameter_1.25, constant_1), padding=0_0x0_128
#   bitcast.1 = f32[32,128,8488]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[128,40,32]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:23:25.323914  971393 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.77 = f32[128,40,32]{2,1,0} fusion(bitcast.694, bitcast.569), kind=kCustom, calls=gemm_fusion_dot.77_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:23:25.324178  971393 xtile_compiler.cc:401] Computation: gemm_fusion_dot.77_computation.clone {
#   parameter_0.24 = f32[40,1086336]{0,1} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[40,1086464]{0,1} pad(parameter_0.24, constant), padding=0_0x0_128
#   bitcast = f32[40,128,8488]{0,2,1} bitcast(pad)
#   parameter_1.24 = f32[1086336,32]{1,0} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[1086464,32]{1,0} pad(parameter_1.24, constant_1), padding=0_128x0_0
#   bitcast.1 = f32[128,8488,32]{2,1,0} bitcast(pad.1)
#   ROOT dot = f32[128,40,32]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0506 09:23:26.031827  971393 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.77 = f32[128,40,32]{2,1,0} fusion(bitcast.694, bitcast.569), kind=kCustom, calls=gemm_fusion_dot.77_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:23:26.031947  971393 xtile_compiler.cc:401] Computation: gemm_fusion_dot.77_computation.clone {
#   parameter_0.24 = f32[40,1086336]{0,1} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[40,1086464]{0,1} pad(parameter_0.24, constant), padding=0_0x0_128
#   bitcast = f32[40,128,8488]{0,2,1} bitcast(pad)
#   parameter_1.24 = f32[1086336,32]{1,0} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[1086464,32]{1,0} pad(parameter_1.24, constant_1), padding=0_128x0_0
#   bitcast.1 = f32[128,8488,32]{2,1,0} bitcast(pad.1)
#   ROOT dot = f32[128,40,32]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0506 09:23:26.130162  971391 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.77 = f32[2,40,32]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.77_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","8"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:23:26.130243  971391 xtile_compiler.cc:401] Computation: gemm_fusion_dot.77_computation.clone {
#   parameter_0.24 = f32[40,2,543168]{0,2,1} parameter(0)
#   parameter_1.24 = f32[2,543168,32]{2,1,0} parameter(1)
#   ROOT dot = f32[2,40,32]{2,1,0} dot(parameter_0.24, parameter_1.24), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# Always recompute the neighbor list!
# [Force] Found precomputed forces.
# [Epoch 0]:
# 	Average train loss: 30768.33929
# 	Average val loss: 26883.8046875
# 	Gradient norm: 41462416.0
# 	Elapsed time = 0.188 min (total), 0.138 min (training)
# 	Per-target losses:
# 		F | train loss: 30768.339285714286 | val loss: 26883.8046875
#
# [Epoch 1]:
# 	Average train loss: 25085.80060
# 	Average val loss: 23765.09765625
# 	Gradient norm: 12432657.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 25085.800595238095 | val loss: 23765.09765625
#
# [Epoch 2]:
# 	Average train loss: 23346.69345
# 	Average val loss: 23074.294921875
# 	Gradient norm: 3849013.75
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 23346.693452380954 | val loss: 23074.294921875
#
# [Epoch 3]:
# 	Average train loss: 22879.48363
# 	Average val loss: 22696.775390625
# 	Gradient norm: 2245339.75
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 22879.48363095238 | val loss: 22696.775390625
#
# [Epoch 4]:
# 	Average train loss: 22542.34821
# 	Average val loss: 22449.34765625
# 	Gradient norm: 838650.25
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 22542.348214285714 | val loss: 22449.34765625
#
# [Epoch 5]:
# 	Average train loss: 22352.45238
# 	Average val loss: 22285.50390625
# 	Gradient norm: 572453.6875
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 22352.45238095238 | val loss: 22285.50390625
#
# [Epoch 6]:
# 	Average train loss: 22183.55804
# 	Average val loss: 22166.27734375
# 	Gradient norm: 4093805.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 22183.558035714286 | val loss: 22166.27734375
#
# [Epoch 7]:
# 	Average train loss: 22160.60417
# 	Average val loss: 22070.337890625
# 	Gradient norm: 3490341.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 22160.604166666668 | val loss: 22070.337890625
#
# [Epoch 8]:
# 	Average train loss: 21982.14881
# 	Average val loss: 21976.009765625
# 	Gradient norm: 14474652.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21982.14880952381 | val loss: 21976.009765625
#
# [Epoch 9]:
# 	Average train loss: 21901.42411
# 	Average val loss: 21884.361328125
# 	Gradient norm: 2065598.75
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21901.42410714286 | val loss: 21884.361328125
#
# [Epoch 10]:
# 	Average train loss: 21849.76339
# 	Average val loss: 21803.412109375
# 	Gradient norm: 5287153.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21849.76339285714 | val loss: 21803.412109375
#
# [Epoch 11]:
# 	Average train loss: 21769.36458
# 	Average val loss: 21717.53125
# 	Gradient norm: 2935096.25
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21769.364583333332 | val loss: 21717.53125
#
# [Epoch 12]:
# 	Average train loss: 21659.83185
# 	Average val loss: 21644.58203125
# 	Gradient norm: 31794948.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21659.831845238095 | val loss: 21644.58203125
#
# [Epoch 13]:
# 	Average train loss: 21603.28423
# 	Average val loss: 21569.42578125
# 	Gradient norm: 28308848.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21603.284226190477 | val loss: 21569.42578125
#
# [Epoch 14]:
# 	Average train loss: 21524.80357
# 	Average val loss: 21499.673828125
# 	Gradient norm: 4647322.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21524.803571428572 | val loss: 21499.673828125
#
# [Epoch 15]:
# 	Average train loss: 21416.46726
# 	Average val loss: 21432.865234375
# 	Gradient norm: 14279542.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21416.467261904763 | val loss: 21432.865234375
#
# [Epoch 16]:
# 	Average train loss: 21406.78571
# 	Average val loss: 21378.669921875
# 	Gradient norm: 4787774.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21406.785714285714 | val loss: 21378.669921875
#
# [Epoch 17]:
# 	Average train loss: 21366.78274
# 	Average val loss: 21343.072265625
# 	Gradient norm: 16595193.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21366.782738095237 | val loss: 21343.072265625
#
# [Epoch 18]:
# 	Average train loss: 21283.89881
# 	Average val loss: 21290.755859375
# 	Gradient norm: 7450028.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21283.89880952381 | val loss: 21290.755859375
#
# [Epoch 19]:
# 	Average train loss: 21263.18006
# 	Average val loss: 21244.19140625
# 	Gradient norm: 19747134.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21263.18005952381 | val loss: 21244.19140625
#
# [Epoch 20]:
# 	Average train loss: 21162.67857
# 	Average val loss: 21215.966796875
# 	Gradient norm: 7156972.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21162.678571428572 | val loss: 21215.966796875
#
# [Epoch 21]:
# 	Average train loss: 21184.57887
# 	Average val loss: 21172.421875
# 	Gradient norm: 63454596.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21184.57886904762 | val loss: 21172.421875
#
# [Epoch 22]:
# 	Average train loss: 21156.78274
# 	Average val loss: 21163.390625
# 	Gradient norm: 25321696.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21156.782738095237 | val loss: 21163.390625
#
# [Epoch 23]:
# 	Average train loss: 21130.42560
# 	Average val loss: 21126.435546875
# 	Gradient norm: 45322760.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21130.425595238095 | val loss: 21126.435546875
#
# [Epoch 24]:
# 	Average train loss: 21095.78125
# 	Average val loss: 21096.01953125
# 	Gradient norm: 121521176.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21095.78125 | val loss: 21096.01953125
#
# [Epoch 25]:
# 	Average train loss: 21062.65923
# 	Average val loss: 21075.490234375
# 	Gradient norm: 13600618.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21062.659226190477 | val loss: 21075.490234375
#
# [Epoch 26]:
# 	Average train loss: 21047.59524
# 	Average val loss: 21063.328125
# 	Gradient norm: 21556778.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21047.595238095237 | val loss: 21063.328125
#
# [Epoch 27]:
# 	Average train loss: 21032.37649
# 	Average val loss: 21047.201171875
# 	Gradient norm: 2145867.75
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21032.376488095237 | val loss: 21047.201171875
#
# [Epoch 28]:
# 	Average train loss: 21020.79167
# 	Average val loss: 21029.123046875
# 	Gradient norm: 279913312.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21020.791666666668 | val loss: 21029.123046875
#
# [Epoch 29]:
# 	Average train loss: 20997.24851
# 	Average val loss: 21009.1484375
# 	Gradient norm: 12950524.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20997.248511904763 | val loss: 21009.1484375
#
# [Epoch 30]:
# 	Average train loss: 21032.54911
# 	Average val loss: 21000.142578125
# 	Gradient norm: 43729692.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 21032.54910714286 | val loss: 21000.142578125
#
# [Epoch 31]:
# 	Average train loss: 20940.59077
# 	Average val loss: 20985.287109375
# 	Gradient norm: 6636319.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20940.590773809523 | val loss: 20985.287109375
#
# [Epoch 32]:
# 	Average train loss: 20988.40030
# 	Average val loss: 20980.888671875
# 	Gradient norm: 60507160.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20988.400297619046 | val loss: 20980.888671875
#
# [Epoch 33]:
# 	Average train loss: 20934.38839
# 	Average val loss: 20984.560546875
# 	Gradient norm: 1706768.25
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20934.38839285714 | val loss: 20984.560546875
#
# [Epoch 34]:
# 	Average train loss: 20966.54167
# 	Average val loss: 20973.4453125
# 	Gradient norm: 8281687.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20966.541666666668 | val loss: 20973.4453125
#
# [Epoch 35]:
# 	Average train loss: 20912.37946
# 	Average val loss: 20956.611328125
# 	Gradient norm: 86227952.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20912.379464285714 | val loss: 20956.611328125
#
# [Epoch 36]:
# 	Average train loss: 20905.53869
# 	Average val loss: 20948.453125
# 	Gradient norm: 49049276.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20905.53869047619 | val loss: 20948.453125
#
# [Epoch 37]:
# 	Average train loss: 20909.75893
# 	Average val loss: 20931.783203125
# 	Gradient norm: 43827664.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20909.758928571428 | val loss: 20931.783203125
#
# [Epoch 38]:
# 	Average train loss: 20947.20387
# 	Average val loss: 20928.474609375
# 	Gradient norm: 100910448.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20947.20386904762 | val loss: 20928.474609375
#
# [Epoch 39]:
# 	Average train loss: 20916.75446
# 	Average val loss: 20914.6328125
# 	Gradient norm: 129782136.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20916.754464285714 | val loss: 20914.6328125
#
# [Epoch 40]:
# 	Average train loss: 20877.42113
# 	Average val loss: 20918.478515625
# 	Gradient norm: 9833850.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20877.42113095238 | val loss: 20918.478515625
#
# [Epoch 41]:
# 	Average train loss: 20890.71429
# 	Average val loss: 20933.2421875
# 	Gradient norm: 38448508.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20890.714285714286 | val loss: 20933.2421875
#
# [Epoch 42]:
# 	Average train loss: 20850.31250
# 	Average val loss: 20896.421875
# 	Gradient norm: 56952128.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20850.3125 | val loss: 20896.421875
#
# [Epoch 43]:
# 	Average train loss: 20903.60268
# 	Average val loss: 20887.201171875
# 	Gradient norm: 10402316.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20903.602678571428 | val loss: 20887.201171875
#
# [Epoch 44]:
# 	Average train loss: 20846.11161
# 	Average val loss: 20883.611328125
# 	Gradient norm: 18510146.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20846.11160714286 | val loss: 20883.611328125
#
# [Epoch 45]:
# 	Average train loss: 20851.20982
# 	Average val loss: 20871.9375
# 	Gradient norm: 178334944.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20851.209821428572 | val loss: 20871.9375
#
# [Epoch 46]:
# 	Average train loss: 20843.63095
# 	Average val loss: 20866.251953125
# 	Gradient norm: 2606184.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20843.630952380954 | val loss: 20866.251953125
#
# [Epoch 47]:
# 	Average train loss: 20846.61756
# 	Average val loss: 20861.51953125
# 	Gradient norm: 12566846.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20846.61755952381 | val loss: 20861.51953125
#
# [Epoch 48]:
# 	Average train loss: 20845.42113
# 	Average val loss: 20852.8203125
# 	Gradient norm: 31521206.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20845.42113095238 | val loss: 20852.8203125
#
# [Epoch 49]:
# 	Average train loss: 20813.17560
# 	Average val loss: 20844.59375
# 	Gradient norm: 5839132.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20813.175595238095 | val loss: 20844.59375
#
# [Epoch 50]:
# 	Average train loss: 20814.07440
# 	Average val loss: 20846.98046875
# 	Gradient norm: 3182689.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20814.074404761905 | val loss: 20846.98046875
#
# [Epoch 51]:
# 	Average train loss: 20830.66667
# 	Average val loss: 20854.599609375
# 	Gradient norm: 62998152.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20830.666666666668 | val loss: 20854.599609375
#
# [Epoch 52]:
# 	Average train loss: 20803.97470
# 	Average val loss: 20833.05859375
# 	Gradient norm: 7757533.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20803.974702380954 | val loss: 20833.05859375
#
# [Epoch 53]:
# 	Average train loss: 20777.23810
# 	Average val loss: 20825.958984375
# 	Gradient norm: 29964612.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20777.238095238095 | val loss: 20825.958984375
#
# [Epoch 54]:
# 	Average train loss: 20821.27827
# 	Average val loss: 20822.599609375
# 	Gradient norm: 28340574.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20821.278273809523 | val loss: 20822.599609375
#
# [Epoch 55]:
# 	Average train loss: 20759.69940
# 	Average val loss: 20816.509765625
# 	Gradient norm: 48447460.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20759.699404761905 | val loss: 20816.509765625
#
# [Epoch 56]:
# 	Average train loss: 20812.64881
# 	Average val loss: 20811.162109375
# 	Gradient norm: 42033692.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20812.64880952381 | val loss: 20811.162109375
#
# [Epoch 57]:
# 	Average train loss: 20789.32143
# 	Average val loss: 20802.681640625
# 	Gradient norm: 91140288.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20789.321428571428 | val loss: 20802.681640625
#
# [Epoch 58]:
# 	Average train loss: 20781.12500
# 	Average val loss: 20798.98046875
# 	Gradient norm: 42859888.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20781.125 | val loss: 20798.98046875
#
# [Epoch 59]:
# 	Average train loss: 20756.26190
# 	Average val loss: 20807.69921875
# 	Gradient norm: 36222704.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20756.261904761905 | val loss: 20807.69921875
#
# [Epoch 60]:
# 	Average train loss: 20786.02381
# 	Average val loss: 20838.05859375
# 	Gradient norm: 17336096.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20786.02380952381 | val loss: 20838.05859375
#
# [Epoch 61]:
# 	Average train loss: 20778.58185
# 	Average val loss: 20784.02734375
# 	Gradient norm: 16190072.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20778.581845238095 | val loss: 20784.02734375
#
# [Epoch 62]:
# 	Average train loss: 20758.60714
# 	Average val loss: 20781.16015625
# 	Gradient norm: 41532392.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20758.60714285714 | val loss: 20781.16015625
#
# [Epoch 63]:
# 	Average train loss: 20756.70238
# 	Average val loss: 20788.5
# 	Gradient norm: 27454676.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20756.70238095238 | val loss: 20788.5
#
# [Epoch 64]:
# 	Average train loss: 20714.00893
# 	Average val loss: 20776.107421875
# 	Gradient norm: 59141812.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20714.008928571428 | val loss: 20776.107421875
#
# [Epoch 65]:
# 	Average train loss: 20768.12500
# 	Average val loss: 20771.744140625
# 	Gradient norm: 37840092.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20768.125 | val loss: 20771.744140625
#
# [Epoch 66]:
# 	Average train loss: 20755.08185
# 	Average val loss: 20765.720703125
# 	Gradient norm: 5021999.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20755.081845238095 | val loss: 20765.720703125
#
# [Epoch 67]:
# 	Average train loss: 20730.17560
# 	Average val loss: 20776.509765625
# 	Gradient norm: 199868464.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20730.175595238095 | val loss: 20776.509765625
#
# [Epoch 68]:
# 	Average train loss: 20719.12649
# 	Average val loss: 20757.8046875
# 	Gradient norm: 4969128.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20719.126488095237 | val loss: 20757.8046875
#
# [Epoch 69]:
# 	Average train loss: 20747.18452
# 	Average val loss: 20779.322265625
# 	Gradient norm: 6186567.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20747.184523809523 | val loss: 20779.322265625
#
# [Epoch 70]:
# 	Average train loss: 20744.99107
# 	Average val loss: 20759.24609375
# 	Gradient norm: 7565272.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20744.991071428572 | val loss: 20759.24609375
#
# [Epoch 71]:
# 	Average train loss: 20721.23065
# 	Average val loss: 20747.12109375
# 	Gradient norm: 6285077.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20721.230654761905 | val loss: 20747.12109375
#
# [Epoch 72]:
# 	Average train loss: 20713.37946
# 	Average val loss: 20746.70703125
# 	Gradient norm: 66313296.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20713.379464285714 | val loss: 20746.70703125
#
# [Epoch 73]:
# 	Average train loss: 20701.96280
# 	Average val loss: 20735.60546875
# 	Gradient norm: 6785360.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20701.962797619046 | val loss: 20735.60546875
#
# [Epoch 74]:
# 	Average train loss: 20716.43304
# 	Average val loss: 20732.595703125
# 	Gradient norm: 154972336.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20716.433035714286 | val loss: 20732.595703125
#
# [Epoch 75]:
# 	Average train loss: 20708.89732
# 	Average val loss: 20744.912109375
# 	Gradient norm: 20016516.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20708.897321428572 | val loss: 20744.912109375
#
# [Epoch 76]:
# 	Average train loss: 20731.19345
# 	Average val loss: 20756.44140625
# 	Gradient norm: 5060757.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20731.193452380954 | val loss: 20756.44140625
#
# [Epoch 77]:
# 	Average train loss: 20704.43601
# 	Average val loss: 20732.095703125
# 	Gradient norm: 17961606.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20704.436011904763 | val loss: 20732.095703125
#
# [Epoch 78]:
# 	Average train loss: 20697.56994
# 	Average val loss: 20727.16796875
# 	Gradient norm: 25846450.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20697.56994047619 | val loss: 20727.16796875
#
# [Epoch 79]:
# 	Average train loss: 20656.22321
# 	Average val loss: 20730.87109375
# 	Gradient norm: 6063287.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20656.223214285714 | val loss: 20730.87109375
#
# [Epoch 80]:
# 	Average train loss: 20745.86161
# 	Average val loss: 20757.228515625
# 	Gradient norm: 14105704.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20745.86160714286 | val loss: 20757.228515625
#
# [Epoch 81]:
# 	Average train loss: 20707.14435
# 	Average val loss: 20721.896484375
# 	Gradient norm: 9276020.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20707.144345238095 | val loss: 20721.896484375
#
# [Epoch 82]:
# 	Average train loss: 20661.60119
# 	Average val loss: 20723.255859375
# 	Gradient norm: 13801075.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20661.60119047619 | val loss: 20723.255859375
#
# [Epoch 83]:
# 	Average train loss: 20687.92113
# 	Average val loss: 20713.244140625
# 	Gradient norm: 67394800.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20687.92113095238 | val loss: 20713.244140625
#
# [Epoch 84]:
# 	Average train loss: 20664.08929
# 	Average val loss: 20717.685546875
# 	Gradient norm: 437473536.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20664.089285714286 | val loss: 20717.685546875
#
# [Epoch 85]:
# 	Average train loss: 20721.44196
# 	Average val loss: 20714.240234375
# 	Gradient norm: 18199396.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20721.441964285714 | val loss: 20714.240234375
#
# [Epoch 86]:
# 	Average train loss: 20688.38244
# 	Average val loss: 20701.404296875
# 	Gradient norm: 64319524.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20688.38244047619 | val loss: 20701.404296875
#
# [Epoch 87]:
# 	Average train loss: 20652.13095
# 	Average val loss: 20702.294921875
# 	Gradient norm: 8252522.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20652.130952380954 | val loss: 20702.294921875
#
# [Epoch 88]:
# 	Average train loss: 20657.26042
# 	Average val loss: 20698.228515625
# 	Gradient norm: 76177240.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20657.260416666668 | val loss: 20698.228515625
#
# [Epoch 89]:
# 	Average train loss: 20688.10863
# 	Average val loss: 20699.3203125
# 	Gradient norm: 9882490.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20688.10863095238 | val loss: 20699.3203125
#
# [Epoch 90]:
# 	Average train loss: 20672.68155
# 	Average val loss: 20695.173828125
# 	Gradient norm: 103624520.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20672.681547619046 | val loss: 20695.173828125
#
# [Epoch 91]:
# 	Average train loss: 20674.19048
# 	Average val loss: 20708.27734375
# 	Gradient norm: 62971288.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20674.190476190477 | val loss: 20708.27734375
#
# [Epoch 92]:
# 	Average train loss: 20651.97321
# 	Average val loss: 20685.072265625
# 	Gradient norm: 4744253.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20651.973214285714 | val loss: 20685.072265625
#
# [Epoch 93]:
# 	Average train loss: 20643.62500
# 	Average val loss: 20695.962890625
# 	Gradient norm: 62354364.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20643.625 | val loss: 20695.962890625
#
# [Epoch 94]:
# 	Average train loss: 20692.12946
# 	Average val loss: 20691.330078125
# 	Gradient norm: 37718104.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20692.129464285714 | val loss: 20691.330078125
#
# [Epoch 95]:
# 	Average train loss: 20622.62798
# 	Average val loss: 20680.017578125
# 	Gradient norm: 29141234.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20622.627976190477 | val loss: 20680.017578125
#
# [Epoch 96]:
# 	Average train loss: 20674.51786
# 	Average val loss: 20687.330078125
# 	Gradient norm: 3350097.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20674.51785714286 | val loss: 20687.330078125
#
# [Epoch 97]:
# 	Average train loss: 20663.79613
# 	Average val loss: 20701.640625
# 	Gradient norm: 24032124.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20663.79613095238 | val loss: 20701.640625
#
# [Epoch 98]:
# 	Average train loss: 20635.19196
# 	Average val loss: 20675.919921875
# 	Gradient norm: 8337061.5
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20635.191964285714 | val loss: 20675.919921875
#
# [Epoch 99]:
# 	Average train loss: 20642.61310
# 	Average val loss: 20670.158203125
# 	Gradient norm: 172618512.0
# 	Elapsed time = 0.011 min (total), 0.009 min (training)
# 	Per-target losses:
# 		F | train loss: 20642.613095238095 | val loss: 20670.158203125

# %% [markdown]
# The next cell compares the training and validation losses of the radial and
# local many-body force-matching models.
#
# The many-body MLP reaches lower training and validation errors than the radial
# model: once $\chi_i$ is mapped to
# a richer descriptor $\mathbf G_i$, the model can represent angular correlations
# that are invisible to an isotropic pair potential. At the same time, the
# absolute errors remain comparatively large. This is again typical of
# coarse-grained force matching, where the reduced model cannot reproduce the
# atomistic forces exactly.

# %%
plt.plot(manybody_fm_trainer.train_losses, label="Many-Body Train Loss")
plt.plot(radial_fm_trainer.train_losses, label="Radial FM Train Loss")
plt.plot(manybody_fm_trainer.val_losses, label="Many-Body Val Loss")
plt.plot(radial_fm_trainer.val_losses, label="Radial FM Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# We now simulate the best many-body force-matching model and compare its
# trajectory-averaged RDF and ADF to the reference curves. This is the structural
# validation step before DiffTRe.
#
# Compared with the radial model, the key question is whether the additional
# angular information in $\mathbf G_i$ improves not only the force-matching loss
# but also the liquid structure, especially the ADF.

# %%
key, split = jax.random.split(key)
reference_state = init_ref_state(
    split, r_init,
    energy_or_force_fn=manybody_energy_fn_template(manybody_fm_trainer.best_params),
    init_sim_kwargs={"mass": masses, "neighbor": nbrs_init}
)

trajectory_generator = ensemble.sampling.trajectory_generator_init(
    sim_template, manybody_energy_fn_template, timings, quantities)

trajectory = trajectory_generator(manybody_fm_trainer.best_params, reference_state, box=box)

print(f"Average kT: {trajectory.aux['kT'].mean()}")
# Out:
# Always recompute the neighbor list!
# Always recompute the neighbor list!
# Always recompute the neighbor list!
# Average kT: 2.4432613849639893

# %%
plt.figure(figsize=(12, 5), layout="constrained")
plt.subplot(1, 2, 1)
plt.plot(rdf_params.rdf_bin_centers, rdf_params.reference, label="Experimental RDF")
plt.plot(rdf_params.rdf_bin_centers, rdf_observable(trajectory.aux), label="Simulated RDF")
plt.xlabel("Distance")
plt.ylabel("RDF")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(adf_params.adf_bin_centers, adf_params.reference, label="Experimental ADF")
plt.plot(adf_params.adf_bin_centers, adf_observable(trajectory.aux), label="Simulated ADF")
plt.legend()
plt.xlabel("Angle")
plt.ylabel("ADF")
# Out:
# Text(0, 0.5, 'ADF')

# %% [markdown]
# ## DiffTRe Fine-Tuning
#
# We now switch from force matching to fitting ensemble-averaged structural
# observables. The trainer is initialized from the best many-body force-matching
# parameters and refines them so that the RDF and ADF agree more closely with the
# target curves.
#
# For a reference trajectory $\{\mathbf R_n\}_{n=1}^N$ generated under a reference potential $\tilde U$, DiffTRe estimates observables under the current model $U_\theta$ by reweighting,
# $$
# \langle a \rangle_\theta \approx \sum_{n=1}^N w_n\, a(\mathbf R_n),
# \qquad
# w_n=
# \frac{\exp\left[-\beta\left(U_\theta(\mathbf R_n)-\tilde U(\mathbf R_n)\right)\right]}
# {\sum_{m=1}^N \exp\left[-\beta\left(U_\theta(\mathbf R_m)-\tilde U(\mathbf R_m)\right)\right]}.
# $$
# With the default loss, the structural targets enter through a weighted mean-squared error,
# $$
# \mathcal L(\theta)
# =
# \gamma_{\mathrm{RDF}} \left\| \hat g_{\mathrm{RDF}} - g_{\theta}^{\mathrm{RDF}} \right\|^2
# +
# \gamma_{\mathrm{ADF}} \left\| \hat g_{\mathrm{ADF}} - g_{\theta}^{\mathrm{ADF}} \right\|^2,
# $$
# and here both weights are set to $1.0$.
#
# The call to `add_statepoint(...)` collects all ingredients for one thermodynamic
# state point: the many-body energy model, the sampling protocol, the state
# variables `box` and `kT`, the instantaneous quantities, the observables, the
# target RDF and ADF curves, the neighbor list, and the initial reference state.
#
# During training, DiffTRe then alternates between three steps:
#
# 1) it generates or reuses a reference trajectory
# 2) it computes reweighted observable averages and the corresponding loss
# 3) it updates the model parameters from the resulting gradients
#
# Trajectory reuse is controlled through the effective sample size
# $$
# N_{\mathrm{eff}} = \exp\left(-\sum_{n=1}^N w_n \log w_n\right),
# $$
# and `reweight_ratio=0.5` means that the stored trajectory is reused as long as
# at least half of the snapshots remain effectively informative; otherwise a new
# trajectory is generated.

# %%
num_iter = 50
lr_decay = optax.polynomial_schedule(init_value=2e-4, end_value=5e-5, power=2, transition_steps=num_iter)
optimizer = optax.adam(learning_rate=lr_decay, b1=0.5, b2=0.75)

difftre_trainer = trainers.Difftre(
    manybody_fm_trainer.best_params,
    optimizer,
    reweight_ratio=0.5)
difftre_trainer.add_statepoint(
    energy_fn_template=manybody_energy_fn_template,
    simulator_template=sim_template,
    timings=timings,
    state_kwargs={"box": box, "kT": kT},
    quantities=quantities,
    observables={
        "rdf": rdf_observable,
        "adf": adf_observable
    },
    targets={
        "rdf": {
            "target": rdf_params.reference,
            "gamma": 1.0
        },
        "adf": {
            "target": adf_params.reference,
            "gamma": 1.0
        }
    },
    neighbor_fn=nbrs_init,
    reference_state=reference_state
)
# Out:
# /ds/project/paul/projects/reactions/external/chemtrain/chemtrain/ensemble/reweighting.py:798: UserWarning: Propagation function is not safe by default. Do not forget to use the wrapper around the compute function to ensure that the neighborlist does not overflow.
#   warnings.warn(
# Always recompute the neighbor list!
# Always recompute the neighbor list!
# [Propagation] Time for trajectory compilation 0: 0.13648008505503337 mins
# [Propagation] Time for trajectory simulation 0: 0.039361258347829185 mins

# %% [markdown]
# This call starts the DiffTRe optimization for the `num_iter` iterations defined
# above. In each step, the trainer evaluates the current model against the
# structural targets, computes the loss from the reweighted RDF and ADF
# observables, and updates the parameters with the optimizer defined above.

# %%
difftre_trainer.train(num_iter)
# Out:
# Always recompute the neighbor list!
# Always recompute the neighbor list!
# Always recompute the neighbor list!
# Always recompute the neighbor list!
# E0506 09:25:14.996966  971378 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.96 = f32[2,40,32]{2,1,0} fusion(bitcast.3, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.96_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","8"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:25:14.997294  971378 xtile_compiler.cc:401] Computation: gemm_fusion_dot.96_computation.clone {
#   parameter_0.27 = f32[2,169740,40]{2,1,0} parameter(0)
#   parameter_1.27 = f32[32,2,169740]{0,2,1} parameter(1)
#   ROOT dot = f32[2,40,32]{2,1,0} dot(parameter_0.27, parameter_1.27), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:25:15.045705  971384 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.96 = f32[128,40,32]{2,1,0} fusion(bitcast.2059, bitcast.2340), kind=kCustom, calls=gemm_fusion_dot.96_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:25:15.045960  971384 xtile_compiler.cc:401] Computation: gemm_fusion_dot.96_computation.clone {
#   parameter_0.27 = f32[339480,40]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[339968,40]{1,0} pad(parameter_0.27, constant), padding=0_488x0_0
#   bitcast = f32[128,2656,40]{2,1,0} bitcast(pad)
#   parameter_1.27 = f32[32,339480]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[32,339968]{0,1} pad(parameter_1.27, constant_1), padding=0_0x0_488
#   bitcast.1 = f32[32,128,2656]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[128,40,32]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# E0506 09:25:15.108185  971377 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.96 = f32[128,40,32]{2,1,0} fusion(bitcast.2059, bitcast.2340), kind=kCustom, calls=gemm_fusion_dot.96_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0506 09:25:15.108618  971377 xtile_compiler.cc:401] Computation: gemm_fusion_dot.96_computation.clone {
#   parameter_0.27 = f32[339480,40]{1,0} parameter(0)
#   constant = f32[] constant(0)
#   pad = f32[339968,40]{1,0} pad(parameter_0.27, constant), padding=0_488x0_0
#   bitcast = f32[128,2656,40]{2,1,0} bitcast(pad)
#   parameter_1.27 = f32[32,339480]{0,1} parameter(1)
#   constant_1 = f32[] constant(0)
#   pad.1 = f32[32,339968]{0,1} pad(parameter_1.27, constant_1), padding=0_0x0_488
#   bitcast.1 = f32[32,128,2656]{0,2,1} bitcast(pad.1)
#   ROOT dot = f32[128,40,32]{2,1,0} dot(bitcast, bitcast.1), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["128"]}
# }
# [Propagate] Effective sample size: 499.99957275390625 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.440 ref_kT = 2.494
# 	Predicted entropy: 0.00385510572232306
# 	Predicted free_energy: 5.1144215831300244e-05
#
# [DiffTRe] Epoch 0
# 	Epoch loss = 0.01180
# 	Gradient norm: 0.11877088248729706
# 	Elapsed time = 0.407 min
# [Propagate] Effective sample size: 15.36678695678711 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.450 ref_kT = 2.494
# 	Predicted entropy: 0.07700962573289871
# 	Predicted free_energy: 222.51895141601562
#
# [DiffTRe] Epoch 1
# 	Epoch loss = 0.00917
# 	Gradient norm: 0.07360345125198364
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 29.996166229248047 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -0.07888463884592056
# 	Predicted free_energy: 424.6820373535156
#
# [DiffTRe] Epoch 2
# 	Epoch loss = 0.00724
# 	Gradient norm: 0.0779612585902214
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 30.166831970214844 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -0.35015782713890076
# 	Predicted free_energy: 609.1372680664062
#
# [DiffTRe] Epoch 3
# 	Epoch loss = 0.00602
# 	Gradient norm: 0.050768397748470306
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 19.570798873901367 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -0.23711851239204407
# 	Predicted free_energy: 955.6810302734375
#
# [DiffTRe] Epoch 4
# 	Epoch loss = 0.00541
# 	Gradient norm: 0.012730512768030167
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 123.40400695800781 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -0.31102272868156433
# 	Predicted free_energy: 1104.0216064453125
#
# [DiffTRe] Epoch 5
# 	Epoch loss = 0.00486
# 	Gradient norm: 0.007191434036940336
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 130.0524139404297 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.441 ref_kT = 2.494
# 	Predicted entropy: -0.3114217221736908
# 	Predicted free_energy: 1240.9229736328125
#
# [DiffTRe] Epoch 6
# 	Epoch loss = 0.00490
# 	Gradient norm: 0.0020671410020440817
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 408.7857971191406 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.441 ref_kT = 2.494
# 	Predicted entropy: 2.4086289405822754
# 	Predicted free_energy: 1285.367919921875
#
# [DiffTRe] Epoch 7
# 	Epoch loss = 0.00478
# 	Gradient norm: 0.002240848494693637
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 293.7074890136719 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.441 ref_kT = 2.494
# 	Predicted entropy: 17.01967430114746
# 	Predicted free_energy: 1296.46630859375
#
# [DiffTRe] Epoch 8
# 	Epoch loss = 0.00463
# 	Gradient norm: 0.0028418332803994417
# 	Elapsed time = 0.019 min
# [Propagate] Effective sample size: 200.86753845214844 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.448 ref_kT = 2.494
# 	Predicted entropy: -0.2851046025753021
# 	Predicted free_energy: 1222.4395751953125
#
# [DiffTRe] Epoch 9
# 	Epoch loss = 0.00454
# 	Gradient norm: 0.014552556909620762
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 142.1783447265625 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -0.49837738275527954
# 	Predicted free_energy: 968.191162109375
#
# [DiffTRe] Epoch 10
# 	Epoch loss = 0.00452
# 	Gradient norm: 0.011672139167785645
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 407.421630859375 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: 30.84829330444336
# 	Predicted free_energy: 962.040283203125
#
# [DiffTRe] Epoch 11
# 	Epoch loss = 0.00428
# 	Gradient norm: 0.0046679857186973095
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 184.4938507080078 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.446 ref_kT = 2.494
# 	Predicted entropy: -0.3072638511657715
# 	Predicted free_energy: 1057.8465576171875
#
# [DiffTRe] Epoch 12
# 	Epoch loss = 0.00437
# 	Gradient norm: 0.021088911220431328
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 243.19557189941406 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: -0.49981069564819336
# 	Predicted free_energy: 897.0068969726562
#
# [DiffTRe] Epoch 13
# 	Epoch loss = 0.00407
# 	Gradient norm: 0.003432462690398097
# 	Elapsed time = 0.063 min
# [Propagate] Effective sample size: 482.6893310546875 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 0.09490236639976501
# 	Predicted free_energy: 849.0982666015625
#
# [DiffTRe] Epoch 14
# 	Epoch loss = 0.00398
# 	Gradient norm: 0.004834012594074011
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 320.0250244140625 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 44.916107177734375
# 	Predicted free_energy: 883.2316284179688
#
# [DiffTRe] Epoch 15
# 	Epoch loss = 0.00386
# 	Gradient norm: 0.0026492979377508163
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 244.20889282226562 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -0.3806340992450714
# 	Predicted free_energy: 857.331298828125
#
# [DiffTRe] Epoch 16
# 	Epoch loss = 0.00384
# 	Gradient norm: 0.0025201744865626097
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 414.0523376464844 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -34.644500732421875
# 	Predicted free_energy: 838.7221069335938
#
# [DiffTRe] Epoch 17
# 	Epoch loss = 0.00378
# 	Gradient norm: 0.0036073338706046343
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 454.1507568359375 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -13.351097106933594
# 	Predicted free_energy: 882.6806640625
#
# [DiffTRe] Epoch 18
# 	Epoch loss = 0.00369
# 	Gradient norm: 0.0007536836783401668
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 418.0865173339844 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -3.9311673641204834
# 	Predicted free_energy: 922.60595703125
#
# [DiffTRe] Epoch 19
# 	Epoch loss = 0.00364
# 	Gradient norm: 0.0020573458168655634
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 353.2786560058594 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -26.961299896240234
# 	Predicted free_energy: 914.8612060546875
#
# [DiffTRe] Epoch 20
# 	Epoch loss = 0.00356
# 	Gradient norm: 0.0023120727855712175
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 300.54022216796875 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.443 ref_kT = 2.494
# 	Predicted entropy: -7.499907970428467
# 	Predicted free_energy: 973.6839599609375
#
# [DiffTRe] Epoch 21
# 	Epoch loss = 0.00349
# 	Gradient norm: 0.0015772629994899035
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 240.19268798828125 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -0.3848496675491333
# 	Predicted free_energy: 965.66796875
#
# [DiffTRe] Epoch 22
# 	Epoch loss = 0.00328
# 	Gradient norm: 0.0018597368616610765
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 379.0643615722656 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -50.20396041870117
# 	Predicted free_energy: 847.475830078125
#
# [DiffTRe] Epoch 23
# 	Epoch loss = 0.00322
# 	Gradient norm: 0.002037286525592208
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 425.1917724609375 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -35.51114273071289
# 	Predicted free_energy: 877.2214965820312
#
# [DiffTRe] Epoch 24
# 	Epoch loss = 0.00315
# 	Gradient norm: 0.0007834715652279556
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 358.48828125 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -46.51125717163086
# 	Predicted free_energy: 870.4760131835938
#
# [DiffTRe] Epoch 25
# 	Epoch loss = 0.00308
# 	Gradient norm: 0.0012291274033486843
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 189.77389526367188 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -0.6082843542098999
# 	Predicted free_energy: 823.8643188476562
#
# [DiffTRe] Epoch 26
# 	Epoch loss = 0.00313
# 	Gradient norm: 0.0012958776205778122
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 469.1481018066406 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -10.945263862609863
# 	Predicted free_energy: 836.7110595703125
#
# [DiffTRe] Epoch 27
# 	Epoch loss = 0.00302
# 	Gradient norm: 0.001325711840763688
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 352.5375671386719 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -6.931238174438477
# 	Predicted free_energy: 903.641845703125
#
# [DiffTRe] Epoch 28
# 	Epoch loss = 0.00292
# 	Gradient norm: 0.0012286565033718944
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 247.3415985107422 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -0.6578803062438965
# 	Predicted free_energy: 905.8745727539062
#
# [DiffTRe] Epoch 29
# 	Epoch loss = 0.00298
# 	Gradient norm: 0.005007564555853605
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 283.99664306640625 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: 11.333251953125
# 	Predicted free_energy: 1045.9635009765625
#
# [DiffTRe] Epoch 30
# 	Epoch loss = 0.00288
# 	Gradient norm: 0.0004255709354765713
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 136.2071533203125 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.449 ref_kT = 2.494
# 	Predicted entropy: -0.5606299638748169
# 	Predicted free_energy: 1113.02197265625
#
# [DiffTRe] Epoch 31
# 	Epoch loss = 0.00298
# 	Gradient norm: 0.014372553676366806
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 330.9012145996094 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.449 ref_kT = 2.494
# 	Predicted entropy: -45.47415542602539
# 	Predicted free_energy: 976.3192749023438
#
# [DiffTRe] Epoch 32
# 	Epoch loss = 0.00283
# 	Gradient norm: 0.0017774300649762154
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 163.21603393554688 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.452 ref_kT = 2.494
# 	Predicted entropy: -0.8430171012878418
# 	Predicted free_energy: 835.0951538085938
#
# [DiffTRe] Epoch 33
# 	Epoch loss = 0.00312
# 	Gradient norm: 0.008791180327534676
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 437.7248840332031 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.452 ref_kT = 2.494
# 	Predicted entropy: 15.126928329467773
# 	Predicted free_energy: 831.479736328125
#
# [DiffTRe] Epoch 34
# 	Epoch loss = 0.00298
# 	Gradient norm: 0.002673831768333912
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 300.2208251953125 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.452 ref_kT = 2.494
# 	Predicted entropy: 28.754518508911133
# 	Predicted free_energy: 839.9248657226562
#
# [DiffTRe] Epoch 35
# 	Epoch loss = 0.00291
# 	Gradient norm: 0.0016771045047789812
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 199.3696746826172 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -0.7297029495239258
# 	Predicted free_energy: 806.0604858398438
#
# [DiffTRe] Epoch 36
# 	Epoch loss = 0.00265
# 	Gradient norm: 0.0032053024042397738
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 433.8995666503906 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -40.12367248535156
# 	Predicted free_energy: 760.9237060546875
#
# [DiffTRe] Epoch 37
# 	Epoch loss = 0.00260
# 	Gradient norm: 0.001029603648930788
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 295.1260986328125 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -78.4875259399414
# 	Predicted free_energy: 736.0531616210938
#
# [DiffTRe] Epoch 38
# 	Epoch loss = 0.00256
# 	Gradient norm: 0.0016497926553711295
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 369.22509765625 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: -44.394622802734375
# 	Predicted free_energy: 791.8889770507812
#
# [DiffTRe] Epoch 39
# 	Epoch loss = 0.00252
# 	Gradient norm: 0.000885503483004868
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 349.6014709472656 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.445 ref_kT = 2.494
# 	Predicted entropy: 9.668641090393066
# 	Predicted free_energy: 866.6919555664062
#
# [DiffTRe] Epoch 40
# 	Epoch loss = 0.00248
# 	Gradient norm: 0.0007137461798265576
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 249.95950317382812 (250.0) -> Recompute is True
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: -0.6974402666091919
# 	Predicted free_energy: 902.1567993164062
#
# [DiffTRe] Epoch 41
# 	Epoch loss = 0.00240
# 	Gradient norm: 0.0020588873885571957
# 	Elapsed time = 0.064 min
# [Propagate] Effective sample size: 363.2369384765625 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 16.055160522460938
# 	Predicted free_energy: 1006.7919311523438
#
# [DiffTRe] Epoch 42
# 	Epoch loss = 0.00236
# 	Gradient norm: 0.00038269226206466556
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 286.9491882324219 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 15.48699951171875
# 	Predicted free_energy: 1017.1520385742188
#
# [DiffTRe] Epoch 43
# 	Epoch loss = 0.00236
# 	Gradient norm: 0.002000503707677126
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 441.9779357910156 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 5.95501184463501
# 	Predicted free_energy: 930.8539428710938
#
# [DiffTRe] Epoch 44
# 	Epoch loss = 0.00233
# 	Gradient norm: 0.0003866683109663427
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 448.54949951171875 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 2.9112355709075928
# 	Predicted free_energy: 901.0520629882812
#
# [DiffTRe] Epoch 45
# 	Epoch loss = 0.00232
# 	Gradient norm: 0.0005485464353114367
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 365.5116271972656 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 7.018383502960205
# 	Predicted free_energy: 925.9439086914062
#
# [DiffTRe] Epoch 46
# 	Epoch loss = 0.00231
# 	Gradient norm: 0.00035401509376242757
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 381.6526794433594 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 5.769848346710205
# 	Predicted free_energy: 901.3267211914062
#
# [DiffTRe] Epoch 47
# 	Epoch loss = 0.00229
# 	Gradient norm: 0.00019124393293168396
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 411.5230407714844 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 1.731933832168579
# 	Predicted free_energy: 868.9681396484375
#
# [DiffTRe] Epoch 48
# 	Epoch loss = 0.00228
# 	Gradient norm: 0.0004224585718475282
# 	Elapsed time = 0.020 min
# [Propagate] Effective sample size: 341.2923278808594 (250.0) -> Recompute is False
# [Statepoint 0]
# 	kT = 2.447 ref_kT = 2.494
# 	Predicted entropy: 2.7676680088043213
# 	Predicted free_energy: 880.5413208007812
#
# [DiffTRe] Epoch 49
# 	Epoch loss = 0.00226
# 	Gradient norm: 0.00035667838528752327
# 	Elapsed time = 0.020 min

# %%
plt.plot(difftre_trainer.batch_losses, label="DiffTRe Train Loss")

# %% [markdown]
# Finally, we compare three quantities on the same axes: the experimental target
# curves, the RDF and ADF obtained from the stored trajectory of the pretrained
# many-body force-matching model (`trajectory.aux`), and the stored DiffTRe
# prediction `difftre_trainer.predictions[0][num_iter - 1]`.
#
# The DiffTRe curves shown here are therefore reweighted predictions from the
# trainer, not observables from a newly simulated fine-tuned trajectory.

# %%
plt.figure(figsize=(12, 5), layout="constrained")
plt.subplot(1, 2, 1)
plt.plot(rdf_params.rdf_bin_centers, difftre_trainer.predictions[0][num_iter - 1]["rdf"], label="DiffTRe")
plt.plot(rdf_params.rdf_bin_centers, rdf_params.reference, label="Experimental RDF")
plt.plot(rdf_params.rdf_bin_centers, rdf_observable(trajectory.aux), label="Simulated RDF")
plt.xlabel("Distance")
plt.ylabel("RDF")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(adf_params.adf_bin_centers, difftre_trainer.predictions[0][num_iter - 1]["adf"], label="DiffTRe")
plt.plot(adf_params.adf_bin_centers, adf_params.reference, label="Experimental ADF")
plt.plot(adf_params.adf_bin_centers, adf_observable(trajectory.aux), label="Simulated ADF")
plt.legend()
plt.xlabel("Angle")
plt.ylabel("ADF")
# Out:
# Text(0, 0.5, 'ADF')

# %% [markdown]
# The comparison shows whether structural fine-tuning improves agreement with the
# reference observables beyond the pretrained many-body simulation. In this plot,
# the DiffTRe prediction moves the RDF and ADF closer to the targets than the
# baseline trajectory in several regions, which is exactly what DiffTRe is meant
# to do.

# %% [markdown]
# ## Outlook: Using MLP in LAMMPS
#
# To use the trained potential in LAMMPS, we need to export it into the `chemtrain-deploy` format expected by the connector. This cell defines the deployment-time energy function and runs the export step that packages the model together with the graph and unit metadata needed later on the LAMMPS side.
#
# One non-obvious part is that the model is rebuilt inside `energy_fn`. The reason is that deployment uses a graph object whose buffer sizes can differ from the training setup, in particular the maximum number of retained edges after pruning. `initialize_model(..., graph.max_edges.size)` recreates an `apply_fn` whose static graph-related shapes match the exported interface, so the compiled model is consistent with the neighbor-list capacity seen during deployment. In the same function, positions are converted back from angstroms to nanometers before evaluation, the species are fixed to a single-species encoding, and the predicted energy is converted from `kJ/mol` to `kcal/mol` to match `unit_style = "real"`.
#
# We stop here at `model.export()`, which is the point where the deployable representation is created. To continue, see:
# - [`chemtrain.deploy.exporter.Exporter`](https://chemtrain.readthedocs.io/en/latest/api/deploy/exporter.html) for the export workflow and the expected `energy_fn`
# - [`chemtrain.deploy.graphs`](https://chemtrain.readthedocs.io/en/latest/api/deploy/graphs.html) for `SimpleDenseNeighborList` and graph buffering
# - [`chemtrain-deploy` Getting Started](https://chemtrain.readthedocs.io/en/latest/chemtrain-deploy/getting_started.html) for loading the exported model in LAMMPS
# - [`chemtrain-deploy` Installation](https://chemtrain.readthedocs.io/en/latest/chemtrain-deploy/installation.html) for setting up the connector and plugin

# %%
from chemtrain.deploy import exporter, graphs

free_displacement, _ = space.free()
class ExportedModel(exporter.Exporter):

    unit_style = 'real'
    r_cutoff = r_cutoff * 10 # Units: A, kcal/mol
    graph_type = graphs.SimpleDenseNeighborList
    nbr_order = [1, 2]

    def energy_fn(self, position, species, graph):
        neighbor = graph.to_neighborlist()

        _, apply_fn = initialize_model(
            architecture, config, r_cutoff, free_displacement, graph.max_edges.size)

        species = jnp.zeros((position.shape[0],), dtype=int)

        position = position / 10.0 # Convert from A to nm
        pot = apply_fn(manybody_fm_trainer.best_params, position, species, neighbor)
        pot /= 4.184 # Convert from kJ/mol to kcal/mol

        return pot.squeeze(axis=-1)

model = ExportedModel()
model.export()
model.save(data_dir / "exported_model.ptb")
# Out:
# Shape of reachable: (n_atoms, max_nbrs)
# Shape of reachable (later): (n_atoms,)
# Shape due to (n_atoms, max_nbrs)
# Shape of reachable: (n_atoms, max_nbrs)
# Shape of reachable (later): (n_atoms,)
# Shape due to (n_atoms, max_nbrs)
